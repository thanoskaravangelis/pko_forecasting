# %%
import pandas as pd

# your file path here
df = pd.read_excel("/Users/athanasioskaravangelis/Desktop/RSM BAM/Workshop/pko_forecasting/data/PKO_Initial_Dataset.xlsx")

# %%
#describe first 12 columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Palmkernel oil(FOB Malaysia)',
#        'Palmkernel oil (CIF Rotterdam)', 'Coconut oil (CIF Rotterdam)',
#        'Palm oil, crude (CIF NWE)', 'Palm olein (FOB Malaysia)',
#        'Palm stearin (CIF Rotterdam)', 'Tallow, edible (FOB US Gulf)',
#        'Soybean Oil, edible (ZLZ2)', '(Bio)-Ethanol',
#        'Fatty Alcohol C12-14 FOB Asia (USD/ton)',
#        'Fatty Alcohol C16-18 FOB Asia (USD/ton)',
#        'Fatty Alcohol C12-14 FD NWE (EUR/ton)', 'RSPO (EUR/ton)',
#        'Jet Fuel Europe (US$/ton)', 'Jet Fuel US ($c/gallon)',
#        'Jet Fuel US US$/MT', 'Palm Oil Harvest Area (M.Ha) - Indonesia',
#        'Palm Oil Production  (M.Tons) - Indonesia',
#        'PKO Production - Indonesia', 'Palm Oil Harvest Area (M.Ha) - Malaysia',
#        'Palm Oil Production  (M.Tons) - Malaysia', 'PKO Production - Malaysia',
#        'PKO Monthly Stocks (M.Tons) - Indonesia',
#        'PKO Monthly Stocks (M.Tons) - Malaysia',
#        'PKO Domestic Consumption (M.Tons) - Indonesia',
#        'PKO Domestic Consumption (M.Tons) - Malaysia',
#        'PKO Exports (M.Tons) - Indonesia', 'PKO Exports (M.Tons) - Malaysia',
#        'PKO Total Supply (M.Tons) - Indonesia',
#        'PKO Total Supply (M.Tons) - Malaysia', 'Ukraine War',
#        'Malaysia-Harvest', 'Malaysia_Disaster', 'Indonesia_Disaster',
#        'Indonesia-Harvest', 'ONI', 'malaysia_temperature', 'malaysia_humidity',
#        'MYR_USD_rate', 'IDR_USD_rate', 'Indonesia PMI', 'Malaysia PMI',
#        'Export_Tarrifs_Indonesia', 'CPOPC_Mal/Ind_2015', 'MSPO Certification',
#        'ISPO Certification', 'Precipitation_Indonesia',
#        'Precipitation_Malaysia', 'Temperaturemin_Indonesia',
#        'Temperaturemin_Malaysia', 'Temperaturemax_Indonesia',
#        'Temperaturemax_Malaysia', 'Humidex_Indonesia', 'Humidex_Malaysia'],
#       dtype='object')

# %%
# these are the columns name
df['date'] = df['Unnamed: 0']
df['pko_fob_malaysia'] = df['Palmkernel oil(FOB Malaysia)']
df['pko_cif_rotterdam'] = df['Palmkernel oil (CIF Rotterdam)']
df['coconut_cif_rotterdam'] = df['Coconut oil (CIF Rotterdam)']
df['palm_oil_cif_nwe'] = df['Palm oil, crude (CIF NWE)']
df['palm_olein_fob_malaysia'] = df['Palm olein (FOB Malaysia)']
df['palm_stearin_cif_rotterdam'] = df['Palm stearin (CIF Rotterdam)']
df['tallow_fob_us_gulf'] = df['Tallow, edible (FOB US Gulf)']
df['soybean_oil_zlz2'] = df['Soybean Oil, edible (ZLZ2)']
df['bio_ethanol'] = df['(Bio)-Ethanol']
df['fatty_alcohol_c12_14_fob_asia'] = df['Fatty Alcohol C12-14 FOB Asia (USD/ton)']
df['fatty_alcohol_c16_18_fob_asia'] = df['Fatty Alcohol C16-18 FOB Asia (USD/ton)']
df['fatty_alcohol_c12_14_fd_nwe'] = df['Fatty Alcohol C12-14 FD NWE (EUR/ton)']
df['rspo'] = df['RSPO (EUR/ton)']
df['jet_fuel_europe'] = df['Jet Fuel Europe (US$/ton)']
df['jet_fuel_us'] = df['Jet Fuel US ($c/gallon)']
df['jet_fuel_us_usd_mt'] = df['Jet Fuel US US$/MT']
df['ukraine_war'] = df['Ukraine War']
df['malaysia_harvest'] = df['Malaysia-Harvest']
df['malaysia_disaster'] = df['Malaysia_Disaster']
df['indonesia_disaster'] = df['Indonesia_Disaster']
df['indonesia_harvest'] = df['Indonesia-Harvest']
df['myr_usd_rate'] = df['MYR_USD_rate']
df['idr_usd_rate'] = df['IDR_USD_rate']

#delete old columns
df = df.drop(columns=['Unnamed: 0', 'Palmkernel oil(FOB Malaysia)', 'Palmkernel oil (CIF Rotterdam)', 'Coconut oil (CIF Rotterdam)', 'Palm oil, crude (CIF NWE)', 'Palm olein (FOB Malaysia)', 'Palm stearin (CIF Rotterdam)', 'Tallow, edible (FOB US Gulf)', 'Soybean Oil, edible (ZLZ2)', '(Bio)-Ethanol', 'Fatty Alcohol C12-14 FOB Asia (USD/ton)', 'Fatty Alcohol C16-18 FOB Asia (USD/ton)', 'Fatty Alcohol C12-14 FD NWE (EUR/ton)', 'RSPO (EUR/ton)', 'Jet Fuel Europe (US$/ton)', 'Jet Fuel US ($c/gallon)', 'Jet Fuel US US$/MT', 'Ukraine War', 'Malaysia-Harvest', 'Malaysia_Disaster', 'Indonesia_Disaster', 'Indonesia-Harvest', 'MYR_USD_rate', 'IDR_USD_rate'])

# %%
# rename columns 
df['palm_oil_harvest_area_indonesia'] = df['Palm Oil Harvest Area (M.Ha) - Indonesia']
df['palm_oil_production_indonesia'] = df['Palm Oil Production  (M.Tons) - Indonesia']
df['pko_production_indonesia'] = df['PKO Production - Indonesia']
df['palm_oil_harvest_area_malaysia'] = df['Palm Oil Harvest Area (M.Ha) - Malaysia']
df['palm_oil_production_malaysia'] = df['Palm Oil Production  (M.Tons) - Malaysia']
df['pko_production_malaysia'] = df['PKO Production - Malaysia']
df['pko_monthly_stocks_indonesia'] = df['PKO Monthly Stocks (M.Tons) - Indonesia']
df['pko_monthly_stocks_malaysia'] = df['PKO Monthly Stocks (M.Tons) - Malaysia']
df['pko_domestic_consumption_indonesia'] = df['PKO Domestic Consumption (M.Tons) - Indonesia']
df['pko_domestic_consumption_malaysia'] = df['PKO Domestic Consumption (M.Tons) - Malaysia']
df['pko_exports_indonesia'] = df['PKO Exports (M.Tons) - Indonesia']
df['pko_exports_malaysia'] = df['PKO Exports (M.Tons) - Malaysia']
df['pko_total_supply_indonesia'] = df['PKO Total Supply (M.Tons) - Indonesia']
df['pko_total_supply_malaysia'] = df['PKO Total Supply (M.Tons) - Malaysia']

#delete old columns
df = df.drop(columns=['Palm Oil Harvest Area (M.Ha) - Indonesia',
       'Palm Oil Production  (M.Tons) - Indonesia',
       'PKO Production - Indonesia', 'Palm Oil Harvest Area (M.Ha) - Malaysia',
       'Palm Oil Production  (M.Tons) - Malaysia', 'PKO Production - Malaysia',
       'PKO Monthly Stocks (M.Tons) - Indonesia',
       'PKO Monthly Stocks (M.Tons) - Malaysia',
       'PKO Domestic Consumption (M.Tons) - Indonesia',
       'PKO Domestic Consumption (M.Tons) - Malaysia',
       'PKO Exports (M.Tons) - Indonesia', 'PKO Exports (M.Tons) - Malaysia',
       'PKO Total Supply (M.Tons) - Indonesia',
       'PKO Total Supply (M.Tons) - Malaysia'])

# rename columns 'Indonesia PMI', 'Malaysia PMI',
#       'Export_Tarrifs_Indonesia', 'CPOPC_Mal/Ind_2015', 'MSPO Certification',
#       'ISPO Certification'
df['pmi_indonesia'] = df['Indonesia PMI']
df['pmi_malaysia'] = df['Malaysia PMI']
df['export_tarrifs_indonesia'] = df['Export_Tarrifs_Indonesia']
df['cpopc_mal_ind_2015'] = df['CPOPC_Mal/Ind_2015']
df['mspo_certification'] = df['MSPO Certification']
df['ispo_certification'] = df['ISPO Certification']

#delete old columns
df = df.drop(columns=['Indonesia PMI', 'Malaysia PMI',
       'Export_Tarrifs_Indonesia', 'CPOPC_Mal/Ind_2015', 'MSPO Certification',
       'ISPO Certification'])


# select only the values after 2010-01-01
# convert date to datetime format , now it is like Jan-06, Feb-06,...., Jan-07 etc and i want to keep only after 2010
df['date'] = pd.to_datetime(df['date'], format='%b-%y')
df = df[df['date'] > '2009-12-02']


df.head()
# Out:
#     ONI  malaysia_temperature  malaysia_humidity  Precipitation_Indonesia  \
# 48  NaN              26.54531           85.46634                 0.418410
# 49  NaN              27.63359           82.16108                 0.347598
# 50  NaN              27.83684           82.11954                 0.429777
# 51  NaN              28.04608           84.09591                 0.412347
# 52  NaN              28.26121           84.52169                 0.402333
#
#     Precipitation_Malaysia  Temperaturemin_Indonesia  Temperaturemin_Malaysia  \
# 48                0.361239                  22.33558                 22.47141
# 49                0.176073                  22.71100                 22.48973
# 50                0.244998                  22.81132                 23.15041
# 51                0.294569                  23.15416                 23.68263
# 52                0.315503                  23.38245                 23.89869
#
#     Temperaturemax_Indonesia  Temperaturemax_Malaysia  Humidex_Indonesia  ...  \
# 48                  30.71202                 31.12185           35.65479  ...
# 49                  31.22701                 32.42118           36.78451  ...
# 50                  31.30822                 33.46994           36.81526  ...
# 51                  31.53292                 32.85302           37.50045  ...
# 52                  31.51028                 32.93819           37.76451  ...
#
#     pko_exports_indonesia pko_exports_malaysia  pko_total_supply_indonesia  \
# 48                    NaN                  NaN                         NaN
# 49                    NaN                  NaN                         NaN
# 50                    NaN                  NaN                         NaN
# 51                    NaN                  NaN                         NaN
# 52                    NaN                  NaN                         NaN
#
#     pko_total_supply_malaysia  pmi_indonesia  pmi_malaysia  \
# 48                        NaN            NaN           NaN
# 49                        NaN            NaN           NaN
# 50                        NaN            NaN           NaN
# 51                        NaN            NaN           NaN
# 52                        NaN            NaN           NaN
#
#     export_tarrifs_indonesia  cpopc_mal_ind_2015  mspo_certification  \
# 48                     100.0                 0.0                 0.0
# 49                     100.0                 0.0                 0.0
# 50                     100.0                 0.0                 0.0
# 51                     100.0                 0.0                 0.0
# 52                     100.0                 0.0                 0.0
#
#     ispo_certification
# 48                 0.0
# 49                 0.0
# 50                 0.0
# 51                 0.0
# 52                 0.0
#
# [5 rows x 55 columns]

# %%
df.shape
# Out:
# (167, 55)

# %%
# check correlation between variables and dependent variable
import seaborn as sns
import matplotlib.pyplot as plt
excl = ['date', 'soybean_oil_zlz2'] 
correlation_check = df.drop(columns=excl)
corr= correlation_check.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split

columns_to_exclude = ['pko_cif_rotterdam', 'pko_fob_malaysia', 'jet_fuel_us', 'jet_fuel_europe', 'date', 'soybean_oil_zlz2', 'tallow_fob_us_gulf', 'bio_ethanol', 'rspo', 'palm_oil_cif_nwe', 'palm_olein_fob_malaysia', 'palm_stearin_cif_rotterdam', 'fatty_alcohol_c12_14_fob_asia', 'fatty_alcohol_c16_18_fob_asia', 'fatty_alcohol_c12_14_fd_nwe', 'jet_fuel_us_usd_mt', 'pmi_indonesia','pmi_malaysia', 'pko_total_supply_malaysia',
                      'indonesia_disaster','Temperaturemin_Malaysia', 'myr_usd_rate', 'export_tarrifs_indonesia']
X = df.drop(columns=columns_to_exclude)
y = df['pko_cif_rotterdam']

X_train = X[0:156]
X_test = X[156:167]
y_train = y[0:156]
y_test = y[156:167]

# %%
# fill nas with average values
X_train = X_train.fillna(X_train.mean())
X_test = X_test.fillna(X_test.mean())

# %%
X_train
# Out:
#           ONI  malaysia_temperature  malaysia_humidity  \
# 48  -0.019167              26.54531           85.46634
# 49  -0.019167              27.63359           82.16108
# 50  -0.019167              27.83684           82.11954
# 51  -0.019167              28.04608           84.09591
# 52  -0.019167              28.26121           84.52169
# ..        ...                   ...                ...
# 199 -0.900000              27.34365           85.91975
# 200 -1.000000              27.16204           85.86312
# 201 -1.000000              26.92022           87.71144
# 202 -0.900000              26.79880           88.64391
# 203 -0.800000              26.28077           88.53871
#
#      Precipitation_Indonesia  Precipitation_Malaysia  \
# 48                  0.418410                0.361239
# 49                  0.347598                0.176073
# 50                  0.429777                0.244998
# 51                  0.412347                0.294569
# 52                  0.402333                0.315503
# ..                       ...                     ...
# 199                 0.339422                0.381834
# 200                 0.324997                0.359636
# 201                 0.412699                0.503676
# 202                 0.443693                0.453881
# 203                 0.404707                0.510806
#
#      Temperaturemin_Indonesia  Temperaturemax_Indonesia  \
# 48                   22.33558                  30.71202
# 49                   22.71100                  31.22701
# 50                   22.81132                  31.30822
# 51                   23.15416                  31.53292
# 52                   23.38245                  31.51028
# ..                        ...                       ...
# 199                  21.35851                  30.67176
# 200                  21.89423                  31.02346
# 201                  22.07912                  30.79115
# 202                  22.42565                  30.79960
# 203                  22.19875                  30.98097
#
#      Temperaturemax_Malaysia  Humidex_Indonesia  Humidex_Malaysia  ...  \
# 48                  31.12185           35.65479          36.57903  ...
# 49                  32.42118           36.78451          37.94791  ...
# 50                  33.46994           36.81526          38.26780  ...
# 51                  32.85302           37.50045          39.29284  ...
# 52                  32.93819           37.76451          39.94663  ...
# ..                       ...                ...               ...  ...
# 199                 32.17313           34.91163          37.82054  ...
# 200                 31.82340           35.27236          37.32779  ...
# 201                 31.70912           35.52293          37.22569  ...
# 202                 31.42695           35.85188          37.25090  ...
# 203                 31.34516           35.47895          36.11195  ...
#
#      pko_monthly_stocks_indonesia  pko_monthly_stocks_malaysia  \
# 48                     280.184875                     344.0212
# 49                     280.184875                     344.0212
# 50                     280.184875                     344.0212
# 51                     280.184875                     344.0212
# 52                     280.184875                     344.0212
# ..                            ...                          ...
# 199                    298.776761                     328.6520
# 200                    304.188677                     339.7080
# 201                    341.503105                     386.0870
# 202                    372.222175                     424.9470
# 203                    268.000000                     404.6180
#
#      pko_domestic_consumption_indonesia  pko_domestic_consumption_malaysia  \
# 48                           218.700492                         109.408005
# 49                           218.700492                         109.408005
# 50                           218.700492                         109.408005
# 51                           218.700492                         109.408005
# 52                           218.700492                         109.408005
# ..                                  ...                                ...
# 199                          318.885538                          78.935000
# 200                          198.219267                          49.066000
# 201                          272.536342                          67.462000
# 202                          543.186075                         134.457000
# 203                          272.209115                          67.381000
#
#      pko_exports_indonesia  pko_exports_malaysia  pko_total_supply_indonesia  \
# 48               86.783333            129.521525                  233.591667
# 49               86.783333            129.521525                  233.591667
# 50               86.783333            129.521525                  233.591667
# 51               86.783333            129.521525                  233.591667
# 52               86.783333            129.521525                  233.591667
# ..                     ...                   ...                         ...
# 199              98.828462            101.363000                  268.444770
# 200              91.649570             94.000000                  248.944964
# 201              92.521216             94.894000                  251.312590
# 202              76.782840             78.752000                  208.562913
# 203             131.090086            134.452000                  356.076046
#
#      cpopc_mal_ind_2015  mspo_certification  ispo_certification
# 48                  0.0                 0.0                 0.0
# 49                  0.0                 0.0                 0.0
# 50                  0.0                 0.0                 0.0
# 51                  0.0                 0.0                 0.0
# 52                  0.0                 0.0                 0.0
# ..                  ...                 ...                 ...
# 199                 1.0                 1.0                 1.0
# 200                 1.0                 1.0                 1.0
# 201                 1.0                 1.0                 1.0
# 202                 1.0                 1.0                 1.0
# 203                 1.0                 1.0                 1.0
#
# [156 rows x 32 columns]

# %%
X_train.shape
# Out:
# (156, 32)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr_train= X.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
# find the features that have the least absolute correlation with pko_cif_rotterdam
# and print them
corr['pko_cif_rotterdam'].abs().sort_values(ascending=True)
# Out:
# idr_usd_rate                          0.005990
# pko_total_supply_malaysia             0.016395
# indonesia_disaster                    0.024334
# Temperaturemax_Malaysia               0.048592
# pko_production_indonesia              0.051839
# Temperaturemin_Malaysia               0.065329
# myr_usd_rate                          0.076873
# mspo_certification                    0.081147
# Humidex_Malaysia                      0.093901
# rspo                                  0.103107
# malaysia_harvest                      0.106035
# cpopc_mal_ind_2015                    0.108468
# malaysia_temperature                  0.112563
# pko_monthly_stocks_indonesia          0.115689
# pko_domestic_consumption_malaysia     0.116955
# malaysia_disaster                     0.117037
# Humidex_Indonesia                     0.118497
# Temperaturemax_Indonesia              0.126335
# indonesia_harvest                     0.134403
# malaysia_humidity                     0.135989
# pko_total_supply_indonesia            0.142838
# pko_domestic_consumption_indonesia    0.152164
# Precipitation_Malaysia                0.157508
# Temperaturemin_Indonesia              0.158194
# palm_oil_harvest_area_malaysia        0.164635
# ukraine_war                           0.172177
# palm_oil_production_indonesia         0.189887
# pko_exports_indonesia                 0.199452
# palm_oil_harvest_area_indonesia       0.232137
# palm_oil_production_malaysia          0.238066
# Precipitation_Indonesia               0.238795
# pmi_malaysia                          0.279760
# export_tarrifs_indonesia              0.283556
# ispo_certification                    0.283981
# jet_fuel_europe                       0.308641
# jet_fuel_us_usd_mt                    0.321462
# jet_fuel_us                           0.321466
# pko_exports_malaysia                  0.341341
# pmi_indonesia                         0.352236
# pko_monthly_stocks_malaysia           0.371402
# pko_production_malaysia               0.441086
# ONI                                   0.497266
# bio_ethanol                           0.585814
# tallow_fob_us_gulf                    0.586652
# fatty_alcohol_c16_18_fob_asia         0.790994
# palm_olein_fob_malaysia               0.795432
# fatty_alcohol_c12_14_fd_nwe           0.799768
# palm_oil_cif_nwe                      0.815903
# palm_stearin_cif_rotterdam            0.849844
# fatty_alcohol_c12_14_fob_asia         0.932837
# coconut_cif_rotterdam                 0.945967
# pko_fob_malaysia                      0.953089
# pko_cif_rotterdam                     1.000000
# Name: pko_cif_rotterdam, dtype: float64

# %%
# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
import math
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
rmse = math.sqrt(mse)
print (mse,rmse)
# Out:
# 26192.31853892767 161.84041071045164

# %%
# get the coefficients in a nicely visual way
pd.DataFrame(zip(X.columns, regressor.coef_))
# Out:
#                                      0             1
# 0                                  ONI -4.707401e+01
# 1                 malaysia_temperature  1.119954e+02
# 2                    malaysia_humidity  1.305743e+01
# 3              Precipitation_Indonesia -1.677637e+01
# 4               Precipitation_Malaysia -9.071697e+00
# 5             Temperaturemin_Indonesia  3.094964e+01
# 6             Temperaturemax_Indonesia  3.847554e+01
# 7              Temperaturemax_Malaysia  6.138426e+01
# 8                    Humidex_Indonesia -1.117510e+01
# 9                     Humidex_Malaysia -1.135332e+02
# 10               coconut_cif_rotterdam  8.909954e-01
# 11                         ukraine_war -4.811162e+01
# 12                    malaysia_harvest -1.536187e+01
# 13                   malaysia_disaster  3.966900e+00
# 14                   indonesia_harvest -2.776894e+01
# 15                        idr_usd_rate  2.520261e+06
# 16     palm_oil_harvest_area_indonesia  1.421507e-01
# 17       palm_oil_production_indonesia -5.091593e-02
# 18            pko_production_indonesia  5.073122e-01
# 19      palm_oil_harvest_area_malaysia -3.437952e-01
# 20        palm_oil_production_malaysia -2.088480e-01
# 21             pko_production_malaysia  2.259243e+00
# 22        pko_monthly_stocks_indonesia  6.193822e-01
# 23         pko_monthly_stocks_malaysia -9.179469e-01
# 24  pko_domestic_consumption_indonesia -1.133869e-01
# 25   pko_domestic_consumption_malaysia  4.060630e-02
# 26               pko_exports_indonesia -7.518016e+00
# 27                pko_exports_malaysia  7.141342e-01
# 28          pko_total_supply_indonesia  2.529815e+00
# 29                  cpopc_mal_ind_2015 -9.394851e+01
# 30                  mspo_certification  5.708143e+01
# 31                  ispo_certification -6.638929e+01

# %%
# get the coefficients
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#                                      Coefficient
# ONI                                -4.707401e+01
# malaysia_temperature                1.119954e+02
# malaysia_humidity                   1.305743e+01
# Precipitation_Indonesia            -1.677637e+01
# Precipitation_Malaysia             -9.071697e+00
# Temperaturemin_Indonesia            3.094964e+01
# Temperaturemax_Indonesia            3.847554e+01
# Temperaturemax_Malaysia             6.138426e+01
# Humidex_Indonesia                  -1.117510e+01
# Humidex_Malaysia                   -1.135332e+02
# coconut_cif_rotterdam               8.909954e-01
# ukraine_war                        -4.811162e+01
# malaysia_harvest                   -1.536187e+01
# malaysia_disaster                   3.966900e+00
# indonesia_harvest                  -2.776894e+01
# idr_usd_rate                        2.520261e+06
# palm_oil_harvest_area_indonesia     1.421507e-01
# palm_oil_production_indonesia      -5.091593e-02
# pko_production_indonesia            5.073122e-01
# palm_oil_harvest_area_malaysia     -3.437952e-01
# palm_oil_production_malaysia       -2.088480e-01
# pko_production_malaysia             2.259243e+00
# pko_monthly_stocks_indonesia        6.193822e-01
# pko_monthly_stocks_malaysia        -9.179469e-01
# pko_domestic_consumption_indonesia -1.133869e-01
# pko_domestic_consumption_malaysia   4.060630e-02
# pko_exports_indonesia              -7.518016e+00
# pko_exports_malaysia                7.141342e-01
# pko_total_supply_indonesia          2.529815e+00
# cpopc_mal_ind_2015                 -9.394851e+01
# mspo_certification                  5.708143e+01
# ispo_certification                 -6.638929e+01

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Assuming you have X_train with predictor variables

# Calculate VIF for each predictor
vif_data = pd.DataFrame()
vif_data["Variable"] = X_train.columns
vif_data["VIF"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]

# Display the VIF data
print(vif_data)

# %%
# plot residuals
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

# %%
# plot two different scatter pplots for prediction and true values with different points
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred, c='g')
plt.scatter(y_test, y_test, c='r')
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()
