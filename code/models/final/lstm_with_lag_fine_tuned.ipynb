# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import pandas as pd
import pickle
import IPython
import IPython.display
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from functions.naming import rename_columns

# %%
# Load the data
df = pd.read_excel("/Users/athanasioskaravangelis/Desktop/RSM BAM/Workshop/pko_forecasting/data/PKO_Initial_Dataset.xlsx")
#rename columns
df = rename_columns(df)
# select only the values after 2010-01-01
df['date'] = pd.to_datetime(df['date'], format='%b-%y')
df = df[df['date'] > '2009-12-02']
#make date the index
df.set_index('date', inplace=True)

# %%
df.columns
# Out:
# Index(['ONI', 'Precipitation_Indonesia', 'Precipitation_Malaysia',
#        'Temperaturemin_Indonesia', 'Temperaturemin_Malaysia',
#        'Temperaturemax_Indonesia', 'Temperaturemax_Malaysia',
#        'Humidex_Indonesia', 'Humidex_Malaysia', 'pko_fob_malaysia',
#        'pko_cif_rotterdam', 'coconut_cif_rotterdam', 'palm_oil_cif_nwe',
#        'palm_olein_fob_malaysia', 'palm_stearin_cif_rotterdam',
#        'tallow_fob_us_gulf', 'soybean_oil_zlz2', 'bio_ethanol',
#        'fatty_alcohol_c12_14_fob_asia', 'fatty_alcohol_c16_18_fob_asia',
#        'fatty_alcohol_c12_14_fd_nwe', 'rspo', 'jet_fuel_europe', 'jet_fuel_us',
#        'jet_fuel_us_usd_mt', 'ukraine_war', 'malaysia_harvest',
#        'malaysia_disaster', 'indonesia_disaster', 'indonesia_harvest',
#        'myr_usd_rate', 'idr_usd_rate', 'palm_oil_harvest_area_indonesia',
#        'palm_oil_production_indonesia', 'pko_production_indonesia',
#        'palm_oil_harvest_area_malaysia', 'palm_oil_production_malaysia',
#        'pko_production_malaysia', 'pko_monthly_stocks_indonesia',
#        'pko_monthly_stocks_malaysia', 'pko_domestic_consumption_indonesia',
#        'pko_domestic_consumption_malaysia', 'pko_exports_indonesia',
#        'pko_exports_malaysia', 'pko_total_supply_indonesia',
#        'pko_total_supply_malaysia', 'pmi_indonesia', 'pmi_malaysia',
#        'export_tarrifs_indonesia', 'cpopc_mal_ind_2015', 'mspo_certification',
#        'ispo_certification'],
#       dtype='object')

# %%
# fill nas with average values
df = df.fillna(df.mean())
data = df.copy()

# %%
# booleans
pko_cif_rotterdam = 1
pko_monthly_stocks_malaysia = 1
pko_monthly_stocks_indonesia = 1
Temperaturemax_Indonesia = 1
Temperaturemin_Malaysia = 1
Temperaturemin_Indonesia = 1
Temperaturemax_Malaysia = 1
Precipitation_Indonesia = 1
Precipitation_Malaysia = 1
Humidex_Indonesia = 1
Humidex_Malaysia = 1
oni = 1
pko_fob_malaysia = 0
coconut_cif_rotterdam = 0
palm_oil_cif_nwe = 0
palm_olein_fob_malaysia = 0
palm_stearin_cif_rotterdam = 0
tallow_fob_us_gulf = 0
soybean_oil_zlz2 = 0
bio_ethanol = 0
fatty_alcohol_c12_14_fob_asia = 0
fatty_alcohol_c16_18_fob_asia = 0
fatty_alcohol_c12_14_fd_nwe = 0
rspo = 0
jet_fuel_europe = 0
jet_fuel_us = 0
jet_fuel_us_usd_mt = 0
ukraine_war = 0
malaysia_harvest = 0
malaysia_disaster = 0
indonesia_disaster = 0
indonesia_harvest = 0
myr_usd_rate = 0
idr_usd_rate = 0
palm_oil_harvest_area_indonesia = 0
palm_oil_production_indonesia = 0
pko_production_indonesia = 0
palm_oil_harvest_area_malaysia = 0
palm_oil_production_malaysia = 0
pko_production_malaysia = 1
pko_domestic_consumption_indonesia = 0
pko_domestic_consumption_malaysia = 0
pko_exports_indonesia = 0
pko_exports_malaysia = 0
pko_total_supply_indonesia = 0
pko_total_supply_malaysia = 0
pmi_indonesia = 0
pmi_malaysia = 0
export_tarrifs_indonesia = 0
cpopc_mal_ind_2015 = 0
mspo_certification = 0
ispo_certification = 0

# put the dataframe columns in the order that you created the booleans
data = data[['pko_cif_rotterdam', 'pko_monthly_stocks_malaysia', 'pko_monthly_stocks_indonesia', 'Temperaturemax_Indonesia',
                'Temperaturemin_Malaysia', 'Temperaturemin_Indonesia', 'Temperaturemax_Malaysia', 'Precipitation_Indonesia',
                'Precipitation_Malaysia', 'Humidex_Indonesia', 'Humidex_Malaysia', 'ONI', 'pko_fob_malaysia',
                'coconut_cif_rotterdam', 'palm_oil_cif_nwe', 'palm_olein_fob_malaysia', 'palm_stearin_cif_rotterdam',
                'tallow_fob_us_gulf', 'soybean_oil_zlz2', 'bio_ethanol', 'fatty_alcohol_c12_14_fob_asia',
                'fatty_alcohol_c16_18_fob_asia', 'fatty_alcohol_c12_14_fd_nwe', 'rspo', 'jet_fuel_europe', 'jet_fuel_us',
                'jet_fuel_us_usd_mt', 'ukraine_war', 'malaysia_harvest', 'malaysia_disaster', 'indonesia_disaster',
                'indonesia_harvest', 'myr_usd_rate', 'idr_usd_rate', 'palm_oil_harvest_area_indonesia',
                'palm_oil_production_indonesia', 'pko_production_indonesia', 'palm_oil_harvest_area_malaysia',
                'palm_oil_production_malaysia', 'pko_production_malaysia', 'pko_domestic_consumption_indonesia',
                'pko_domestic_consumption_malaysia', 'pko_exports_indonesia', 'pko_exports_malaysia',
                'pko_total_supply_indonesia', 'pko_total_supply_malaysia', 'pmi_indonesia', 'pmi_malaysia',
                'export_tarrifs_indonesia', 'cpopc_mal_ind_2015', 'mspo_certification', 'ispo_certification']]

# add these in a list
variables_list = [pko_cif_rotterdam, pko_monthly_stocks_malaysia, pko_monthly_stocks_indonesia, Temperaturemax_Indonesia,
                Temperaturemin_Malaysia, Temperaturemin_Indonesia, Temperaturemax_Malaysia, Precipitation_Indonesia,
                Precipitation_Malaysia, Humidex_Indonesia, Humidex_Malaysia, oni, pko_fob_malaysia, coconut_cif_rotterdam,
                palm_oil_cif_nwe, palm_olein_fob_malaysia, palm_stearin_cif_rotterdam, tallow_fob_us_gulf,
                soybean_oil_zlz2, bio_ethanol, fatty_alcohol_c12_14_fob_asia, fatty_alcohol_c16_18_fob_asia,
                fatty_alcohol_c12_14_fd_nwe, rspo, jet_fuel_europe, jet_fuel_us, jet_fuel_us_usd_mt, ukraine_war,
                malaysia_harvest, malaysia_disaster, indonesia_disaster, indonesia_harvest, myr_usd_rate, idr_usd_rate,
                palm_oil_harvest_area_indonesia, palm_oil_production_indonesia, pko_production_indonesia,
                palm_oil_harvest_area_malaysia, palm_oil_production_malaysia, pko_production_malaysia,
                pko_domestic_consumption_indonesia, pko_domestic_consumption_malaysia, pko_exports_indonesia,
                pko_exports_malaysia, pko_total_supply_indonesia, pko_total_supply_malaysia, pmi_indonesia,
                pmi_malaysia, export_tarrifs_indonesia, cpopc_mal_ind_2015, mspo_certification, ispo_certification]

# create a list with the columns that i want to keep
keep_columns = []
# do a loop to add the columns that i want to keep
for i in range(len(variables_list)):
    if variables_list[i] == 1:
        keep_columns.append(data.columns[i])

# drop the columns that i do not want to keep
data = data[keep_columns]
data.head()
# Out:
#             pko_cif_rotterdam  pko_monthly_stocks_malaysia  \
# date
# 2010-01-01              878.0                   347.569305
# 2010-02-01              894.0                   347.569305
# 2010-03-01              995.0                   347.569305
# 2010-04-01             1020.0                   347.569305
# 2010-05-01             1030.0                   347.569305
#
#             pko_monthly_stocks_indonesia  Temperaturemax_Indonesia  \
# date
# 2010-01-01                    278.311167                  30.71202
# 2010-02-01                    278.311167                  31.22701
# 2010-03-01                    278.311167                  31.30822
# 2010-04-01                    278.311167                  31.53292
# 2010-05-01                    278.311167                  31.51028
#
#             Temperaturemin_Malaysia  Temperaturemin_Indonesia  \
# date
# 2010-01-01                 22.47141                  22.33558
# 2010-02-01                 22.48973                  22.71100
# 2010-03-01                 23.15041                  22.81132
# 2010-04-01                 23.68263                  23.15416
# 2010-05-01                 23.89869                  23.38245
#
#             Temperaturemax_Malaysia  Precipitation_Indonesia  \
# date
# 2010-01-01                 31.12185                 0.418410
# 2010-02-01                 32.42118                 0.347598
# 2010-03-01                 33.46994                 0.429777
# 2010-04-01                 32.85302                 0.412347
# 2010-05-01                 32.93819                 0.402333
#
#             Precipitation_Malaysia  Humidex_Indonesia  Humidex_Malaysia  \
# date
# 2010-01-01                0.361239           35.65479          36.57903
# 2010-02-01                0.176073           36.78451          37.94791
# 2010-03-01                0.244998           36.81526          38.26780
# 2010-04-01                0.294569           37.50045          39.29284
# 2010-05-01                0.315503           37.76451          39.94663
#
#                  ONI  pko_production_malaysia
# date
# 2010-01-01  0.043511               185.118824
# 2010-02-01  0.043511               185.118824
# 2010-03-01  0.043511               185.118824
# 2010-04-01  0.043511               185.118824
# 2010-05-01  0.043511               185.118824

# %%
data.shape
# Out:
# (167, 13)

# %%
# i want to create a dataframe with the averages for each month of the year using values from 2021,2022,2023 of the features that I want to use
# for the forecasting, first i need to create a column with the month of each date
averages_df = data.copy()

averages_df['month'] = averages_df.index.month
averages_df['year'] = averages_df.index.year

# i want to use the values from 2021,2022,2023 to create the averages
averages_df = averages_df[averages_df['year'] > 2020]

# i want to use the values from 2021,2022,2023 to create the averages
averages_df = averages_df[averages_df['year'] < 2024]

# average all features by month
averages_df = averages_df.groupby(['month']).mean()
# ASSUME THAT ONI DECREASES BY 0.1 EVERY MONTH AFTER the last row of the data dataframe
for i in range(1, data.shape[1]):
    # if ONI in columns
    if averages_df.columns[i] == 'ONI':
        # then take the last value of the data dataframe and subtract 0.1
        averages_df.loc[i, 'ONI'] = data['ONI'].iloc[-1] - (0.1 * i)

averages_df_arr = averages_df.values[:, :13]
averages_df_arr.shape

average_scaler = MinMaxScaler(feature_range=(0, 1))
averages_df_arr = average_scaler.fit_transform(averages_df_arr)
averages_df_arr.shape
# Out:
# (12, 13)

# %%
averages_df.iloc[:,:13]
# Out:
#        pko_cif_rotterdam  pko_monthly_stocks_malaysia  \
# month
# 1            1526.000000                   326.558333
# 2            1608.000000                   326.928333
# 3            1625.333333                   316.699000
# 4            1502.666667                   298.034667
# 5            1420.000000                   299.960667
# 6            1264.000000                   314.230000
# 7            1168.000000                   314.907333
# 8            1178.666667                   328.009667
# 9            1190.000000                   339.186667
# 10           1238.666667                   370.168000
# 11           1365.000000                   383.263000
# 12           1457.500000                   333.475000
#
#        pko_monthly_stocks_indonesia  Temperaturemax_Indonesia  \
# month
# 1                        338.666667                 30.672870
# 2                        340.844771                 30.625740
# 3                        319.888850                 31.121203
# 4                        281.845901                 31.279240
# 5                        285.886228                 31.405210
# 6                        311.507651                 30.816287
# 7                        301.047049                 30.650657
# 8                        308.322104                 30.786587
# 9                        318.534064                 31.311123
# 10                       341.643187                 31.773533
# 11                       344.125238                 31.412637
# 12                       300.000000                 31.122725
#
#        Temperaturemin_Malaysia  Temperaturemin_Indonesia  \
# month
# 1                    22.382103                 22.286473
# 2                    22.369263                 22.321783
# 3                    22.695320                 22.320323
# 4                    23.309033                 22.298330
# 5                    23.741813                 22.403200
# 6                    23.366980                 21.803143
# 7                    23.461750                 20.823597
# 8                    23.142097                 21.263717
# 9                    23.188563                 21.465527
# 10                   23.298387                 22.161023
# 11                   23.357847                 22.598167
# 12                   22.751160                 22.335145
#
#        Temperaturemax_Malaysia  Precipitation_Indonesia  \
# month
# 1                    31.284627                 0.390235
# 2                    32.092433                 0.386980
# 3                    32.674807                 0.414661
# 4                    32.708507                 0.326639
# 5                    32.986637                 0.333034
# 6                    32.524433                 0.305619
# 7                    32.510290                 0.291661
# 8                    32.319517                 0.290233
# 9                    32.135433                 0.308596
# 10                   32.351937                 0.305609
# 11                   31.791863                 0.409752
# 12                   31.544200                 0.421295
#
#        Precipitation_Malaysia  Humidex_Indonesia  Humidex_Malaysia       ONI  \
# month
# 1                    0.393778          35.511043         36.134640 -0.900000
# 2                    0.311523          35.510297         36.497413 -0.733333
# 3                    0.339237          36.068627         37.483737 -0.633333
# 4                    0.288487          36.453110         38.435567 -0.533333
# 5                    0.313278          36.850897         39.372327 -0.333333
# 6                    0.307158          35.802767         38.417077 -0.166667
# 7                    0.257935          34.871230         38.466457 -0.033333
# 8                    0.390071          34.675223         37.923937 -0.033333
# 9                    0.393367          34.921390         37.747960 -0.033333
# 10                   0.425219          35.950070         38.030297  0.000000
# 11                   0.478680          36.383680         37.648843  0.800000
# 12                   0.459149          35.828810         36.594650 -0.900000
#
#        pko_production_malaysia
# month
# 1                   148.095000
# 2                   136.496667
# 3                   160.858333
# 4                   158.986333
# 5                   166.191667
# 6                   174.822333
# 7                   174.904667
# 8                   191.928000
# 9                   192.029000
# 10                  203.867000
# 11                  193.297000
# 12                  183.596500

# %%
data.shape
# Out:
# (167, 11)

# %%
data.columns
# Out:
# Index(['pko_cif_rotterdam', 'pko_monthly_stocks_malaysia',
#        'pko_monthly_stocks_indonesia', 'Temperaturemax_Indonesia',
#        'Temperaturemin_Malaysia', 'Temperaturemin_Indonesia',
#        'Temperaturemax_Malaysia', 'Precipitation_Indonesia',
#        'Precipitation_Malaysia', 'Humidex_Indonesia', 'Humidex_Malaysia'],
#       dtype='object')

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# convert series to 
def series_to_supervised(data, n_feat, n_in=1, n_out=1):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	# select only first 11 from df
	#df_custom = df.iloc[:, 0:11]
	# put the rest of the columns in df_rest
	df_rest = df.iloc[:, 11:]
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_feat)]
	# put it all together with df_rest
	#cols.append(df_rest)
	# append the rest of the column names
	#names += df_rest.columns.tolist()
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_feat)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_feat)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	agg.dropna(inplace=True)
	return agg

# %%
def fine_tune_and_visualize(data, batch_sizes, n_months_options, future_steps):
        # Define other parameters like n_features, n_train_months here or calculate based on data
    for test_months in [24]:  
        for batch_size in batch_sizes:
            for n_months in n_months_options:
                print(f"Training model with batch_size={batch_size}, n_months={n_months}, and test_months={test_months}...")

                # Prepare the data for this configuration (use your existing data preparation code)
                # Our best model up until now: n_months = 6, n_features = 12, n_train_months = 149
                n_features = data.shape[1]
                values = data.values
                # keep only the first 11 columns
                values = values[:, 0:n_features]
                # normalize features
                scaler = MinMaxScaler(feature_range=(0, 1))
                scaled = scaler.fit_transform(values)
                # specify the number of lag months
                n_months = n_months
                n_rest = 21
                # frame as 
                reframed = series_to_supervised(scaled, n_features, n_months, 1)
                print("Our total data have shape: ",reframed.shape)

                # Split in train and test
                values=reframed.values
                n_train_months = reframed.shape[0] - test_months
                train = values[:n_train_months, :]
                test = values[n_train_months:, :]

                print("Train and test shapes are: ", train.shape, test.shape)

                # split into input and outputs
                n_obs = n_months * n_features
                train_X, train_y = train[:, :n_obs], train[:, -n_features]
                test_X, test_y = test[:, :n_obs], test[:, -n_features]
                # reshape input to be 3D [samples, timesteps, features]
                train_X = train_X.reshape((train_X.shape[0], n_months, n_features))
                test_X = test_X.reshape((test_X.shape[0], n_months, n_features))
                print("Train X,y and Test X,y are: ", train_X.shape, train_y.shape, test_X.shape, test_y.shape)


                import matplotlib.pyplot as plt
                import matplotlib.dates as mdates
                from datetime import timedelta
                # Define and train the model (use your model training code)
                # design network LSTM
                model = Sequential()
                model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
                model.add(Dense(1))
                model.compile(loss='mean_squared_error', optimizer='adam')
                # fit network
                history = model.fit(train_X, train_y, epochs=100, batch_size=batch_size, validation_data=(test_X, test_y), verbose=2, shuffle=False)
                # plot history
                plt.plot(history.history['loss'], label='train')
                plt.plot(history.history['val_loss'], label='test')
                plt.legend()
                plt.show()

                #from keras.layers import GRU
                # design network
                #model2 = Sequential()
                #model2.add(GRU(50, input_shape=(train_X.shape[1], train_X.shape[2])))
                #model2.add(Dense(1))
                #model2.compile(loss='mean_squared_error', optimizer='adam')
                # fit network
                #history = model2.fit(train_X, train_y, epochs=100, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
                ## plot history
                #plt.plot(history.history['loss'], label='train')
                #plt.plot(history.history['val_loss'], label='test')
                #plt.legend()
                #plt.show()

                # for LSTM  
                # Generate predictions for the test set and calculate RMSE
                test_X_reshaped = test_X.reshape((test_X.shape[0], n_months, n_features))
                yhat = model.predict(test_X_reshaped)
                yhat

                test_X = test_X.reshape((test_X.shape[0], n_months*n_features))
                test_X.shape

                # invert scaling for forecast
                inv_yhat = concatenate((yhat, test_X[:, -((n_features-1)):]), axis=1)
                inv_yhat = scaler.inverse_transform(inv_yhat)
                inv_yhat = inv_yhat[:,0]
                # invert scaling for actual
                test_y = test_y.reshape((len(test_y), 1))
                inv_y = concatenate((test_y, test_X[:, -(n_features-1):]), axis=1)
                inv_y = scaler.inverse_transform(inv_y)
                inv_y = inv_y[:,0]
                # calculate 
                rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
                print('Test RMSE for LSTM: %.3f' % rmse)

                # Print test set graph:
                # plot the actual and predicted values for the test data , x-axis should be date
                plt.figure(figsize=(15, 5))
                plt.rcParams['lines.linewidth'] = 3
                plt.plot(data.index[-(test_y.shape[0]):], inv_y, label='Actual', color='#929292')
                plt.plot(data.index[-(test_y.shape[0]):], inv_yhat, label='Predicted', color='#A20000')
                plt.legend()
                plt.show()

                # create a dataframe with the dates, inv_yhat and inv_y
                dates = data.index[n_train_months+n_months:]
                dates = dates.strftime('%b-%y')
                df_results = pd.DataFrame({'date': dates, 'prediction': inv_yhat, 'actual': inv_y})
                df_results.to_excel(f"test_data_batch_{batch_size}_nmonths_{n_months}.xlsx")
                print("Test set results: ")
                print(df_results)

                # Assuming df_results is your DataFrame with 'date', 'prediction', and 'actual' columns
                plt.figure(figsize=(15, 5))
                plt.ylim(0, 2500)

                # Convert dates to matplotlib date format
                dates = mdates.date2num(df_results['date'])

                # Width of a bar
                bar_width = 10  # You might need to adjust this based on your date scale

                # Plotting
                # GIVE ME LIGHT GRAY COLOR FOR THE FIRST BAR
                plt.bar(dates - bar_width/2, df_results['actual'], width=bar_width, color='#929292', align='center', label='Actual')
                plt.bar(dates + bar_width/2, df_results['prediction'], width=bar_width, color='#A20000', align='center', label='Prediction')

                # Formatting dates on the x-axis
                plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
                plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
                plt.gcf().autofmt_xdate()  # Rotation

                plt.legend()
                plt.show()

                
                # Forecast future values (use your forecasting code)
                test_X = test_X.reshape((test_X.shape[0], n_months, n_features))

                # Forecasting with dynamic feature update using monthly averages
                last_sequence = test_X[-1]  # Last known sequence
                forecast = []

                for i in range(future_steps):
                    # Predict the next step
                    prediction = model.predict(last_sequence.reshape(1, n_months, n_features))
                    forecast.append(prediction[0, 0])
                    
                    # Update the sequence
                    new_sequence = np.roll(last_sequence, -1, axis=1)

                    # Update the target feature with the prediction
                    new_sequence[-1, 0] = prediction[0, 0]

                    # Update other features with their respective monthly averages
                    # Assuming the month for forecasting is determined by (current month + i) % 12
                    forecast_month = (averages_df.index[-1] + i) % 12 + 1
                    monthly_averages = averages_df_arr[forecast_month - 1, 1:13]  # Get the averages for the forecast month
                    new_sequence[-1, 1:] = monthly_averages # Update other features with monthly averages

                    last_sequence = new_sequence

                # Prepare the data for inverse transformation
                forecast_data = np.zeros((len(forecast), n_features))
                forecast_data[:, 0] = forecast  # Update the target feature with forecasted values
                forecast_data[:, 1:] = last_sequence[-1, 1:]  # Update with the last known feature values

                inv_forecast = scaler.inverse_transform(forecast_data)
                inv_forecast = inv_forecast[:, 0]  # Extract the forecasted target values

                # Create a DataFrame for the forecasted values
                forecast_dates = pd.date_range(start=df.index[-1], periods=future_steps + 1, freq='MS')[1:]
                forecast_dates = dates.strftime('%b-%y')
                forecast_df = pd.DataFrame({'date': forecast_dates, 'forecasted_data': inv_forecast})
                # save as excel
                forecast_df.to_excel(f"forecasted_data_batch_{batch_size}_nmonths_{n_months}.xlsx")
                
                # Print or visualize the forecasted data
                print("Forecasted dataframe: ")
                print(forecast_df)

                # DataFrames for results and forecast
                # make plot line bold and bigger
                plt.rcParams['lines.linewidth'] = 3
                plt.figure(figsize=(12, 6))
                plt.plot(df.index[72:n_train_months+n_months], df['pko_fob_malaysia'][72:n_train_months+n_months], label='Train True Values', color='#929292')
                plt.plot(df.index[n_train_months+n_months:], df['pko_fob_malaysia'][n_train_months+n_months:], label='Test True Values')
                #plot with dashed line the line connecting the last value of train and first value of test set
                #plt.plot([df.index[n_train_months+n_months-1], df.index[n_train_months+n_months]], [df['pko_cif_rotterdam'][n_train_months+n_months-1], df['pko_cif_rotterdam'][n_train_months+n_months]], linestyle='dashed')
                # also plot the predicted test values
                plt.plot(df_results['date'], df_results['prediction'], label='Predicted Test Values', color='#A20000')
                plt.plot(forecast_df.index, forecast_df['forecasted_data'], label='Forecasted Values', color='red')
                plt.title('LSTM Model Predictions')
                plt.xlabel('Date')
                plt.ylabel('Palm Kernel Oil Price (FOB Malaysia)')
                # add a nice theme 
                plt.style.use('seaborn-v0_8-pastel')
                plt.legend()
                plt.show()

                # Print RMSE, specs, and DataFrames
                print(f"Specs: batch_size={batch_size}, n_months={n_months}, RMSE={rmse}")

# Call the function with the desired parameters
fine_tune_and_visualize(data, batch_sizes=[18, 24, 32, 36], n_months_options=[1], future_steps=6)
# Out:
# Training model with batch_size=18, n_months=1, and test_months=24...
# Our total data have shape:  (166, 26)
# Train and test shapes are:  (142, 26) (24, 26)
# Train X,y and Test X,y are:  (142, 1, 13) (142,) (24, 1, 13) (24,)
# Epoch 1/100
# 8/8 - 5s - loss: 0.1720 - val_loss: 0.2268 - 5s/epoch - 575ms/step
# Epoch 2/100
# 8/8 - 1s - loss: 0.0870 - val_loss: 0.1358 - 876ms/epoch - 110ms/step
# Epoch 3/100
# 8/8 - 1s - loss: 0.0476 - val_loss: 0.0900 - 607ms/epoch - 76ms/step
# Epoch 4/100
# 8/8 - 0s - loss: 0.0372 - val_loss: 0.0732 - 402ms/epoch - 50ms/step
# Epoch 5/100
# 8/8 - 0s - loss: 0.0361 - val_loss: 0.0687 - 381ms/epoch - 48ms/step
# Epoch 6/100
# 8/8 - 0s - loss: 0.0341 - val_loss: 0.0687 - 439ms/epoch - 55ms/step
# Epoch 7/100
# 8/8 - 0s - loss: 0.0318 - val_loss: 0.0702 - 234ms/epoch - 29ms/step
# Epoch 8/100
# 8/8 - 0s - loss: 0.0307 - val_loss: 0.0708 - 400ms/epoch - 50ms/step
# Epoch 9/100
# 8/8 - 0s - loss: 0.0301 - val_loss: 0.0694 - 118ms/epoch - 15ms/step
# Epoch 10/100
# 8/8 - 0s - loss: 0.0294 - val_loss: 0.0666 - 197ms/epoch - 25ms/step
# Epoch 11/100
# 8/8 - 0s - loss: 0.0286 - val_loss: 0.0635 - 93ms/epoch - 12ms/step
# Epoch 12/100
# 8/8 - 0s - loss: 0.0277 - val_loss: 0.0607 - 189ms/epoch - 24ms/step
# Epoch 13/100
# 8/8 - 0s - loss: 0.0268 - val_loss: 0.0584 - 124ms/epoch - 16ms/step
# Epoch 14/100
# 8/8 - 0s - loss: 0.0259 - val_loss: 0.0563 - 93ms/epoch - 12ms/step
# Epoch 15/100
# 8/8 - 0s - loss: 0.0250 - val_loss: 0.0543 - 98ms/epoch - 12ms/step
# Epoch 16/100
# 8/8 - 0s - loss: 0.0242 - val_loss: 0.0523 - 91ms/epoch - 11ms/step
# Epoch 17/100
# 8/8 - 0s - loss: 0.0234 - val_loss: 0.0502 - 146ms/epoch - 18ms/step
# Epoch 18/100
# 8/8 - 0s - loss: 0.0226 - val_loss: 0.0480 - 90ms/epoch - 11ms/step
# Epoch 19/100
# 8/8 - 0s - loss: 0.0218 - val_loss: 0.0460 - 152ms/epoch - 19ms/step
# Epoch 20/100
# 8/8 - 0s - loss: 0.0210 - val_loss: 0.0439 - 119ms/epoch - 15ms/step
# Epoch 21/100
# 8/8 - 0s - loss: 0.0202 - val_loss: 0.0419 - 193ms/epoch - 24ms/step
# Epoch 22/100
# 8/8 - 0s - loss: 0.0194 - val_loss: 0.0400 - 132ms/epoch - 17ms/step
# Epoch 23/100
# 8/8 - 0s - loss: 0.0187 - val_loss: 0.0380 - 95ms/epoch - 12ms/step
# Epoch 24/100
# 8/8 - 0s - loss: 0.0179 - val_loss: 0.0361 - 91ms/epoch - 11ms/step
# Epoch 25/100
# 8/8 - 0s - loss: 0.0172 - val_loss: 0.0342 - 92ms/epoch - 12ms/step
# Epoch 26/100
# 8/8 - 0s - loss: 0.0164 - val_loss: 0.0324 - 81ms/epoch - 10ms/step
# Epoch 27/100
# 8/8 - 0s - loss: 0.0157 - val_loss: 0.0306 - 84ms/epoch - 10ms/step
# Epoch 28/100
# 8/8 - 0s - loss: 0.0150 - val_loss: 0.0288 - 138ms/epoch - 17ms/step
# Epoch 29/100
# 8/8 - 0s - loss: 0.0143 - val_loss: 0.0271 - 87ms/epoch - 11ms/step
# Epoch 30/100
# 8/8 - 0s - loss: 0.0136 - val_loss: 0.0255 - 83ms/epoch - 10ms/step
# Epoch 31/100
# 8/8 - 0s - loss: 0.0129 - val_loss: 0.0239 - 92ms/epoch - 11ms/step
# Epoch 32/100
# 8/8 - 0s - loss: 0.0123 - val_loss: 0.0223 - 127ms/epoch - 16ms/step
# Epoch 33/100
# 8/8 - 0s - loss: 0.0116 - val_loss: 0.0209 - 115ms/epoch - 14ms/step
# Epoch 34/100
# 8/8 - 0s - loss: 0.0110 - val_loss: 0.0195 - 94ms/epoch - 12ms/step
# Epoch 35/100
# 8/8 - 0s - loss: 0.0104 - val_loss: 0.0182 - 94ms/epoch - 12ms/step
# Epoch 36/100
# 8/8 - 0s - loss: 0.0099 - val_loss: 0.0169 - 98ms/epoch - 12ms/step
# Epoch 37/100
# 8/8 - 0s - loss: 0.0093 - val_loss: 0.0158 - 90ms/epoch - 11ms/step
# Epoch 38/100
# 8/8 - 0s - loss: 0.0088 - val_loss: 0.0147 - 91ms/epoch - 11ms/step
# Epoch 39/100
# 8/8 - 0s - loss: 0.0083 - val_loss: 0.0138 - 87ms/epoch - 11ms/step
# Epoch 40/100
# 8/8 - 0s - loss: 0.0079 - val_loss: 0.0129 - 109ms/epoch - 14ms/step
# Epoch 41/100
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0121 - 88ms/epoch - 11ms/step
# Epoch 42/100
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0114 - 85ms/epoch - 11ms/step
# Epoch 43/100
# 8/8 - 0s - loss: 0.0068 - val_loss: 0.0108 - 82ms/epoch - 10ms/step
# Epoch 44/100
# 8/8 - 0s - loss: 0.0064 - val_loss: 0.0103 - 88ms/epoch - 11ms/step
# Epoch 45/100
# 8/8 - 0s - loss: 0.0061 - val_loss: 0.0098 - 84ms/epoch - 11ms/step
# Epoch 46/100
# 8/8 - 0s - loss: 0.0059 - val_loss: 0.0094 - 81ms/epoch - 10ms/step
# Epoch 47/100
# 8/8 - 0s - loss: 0.0056 - val_loss: 0.0091 - 86ms/epoch - 11ms/step
# Epoch 48/100
# 8/8 - 0s - loss: 0.0054 - val_loss: 0.0088 - 95ms/epoch - 12ms/step
# Epoch 49/100
# 8/8 - 0s - loss: 0.0052 - val_loss: 0.0085 - 79ms/epoch - 10ms/step
# Epoch 50/100
# 8/8 - 0s - loss: 0.0050 - val_loss: 0.0083 - 83ms/epoch - 10ms/step
# Epoch 51/100
# 8/8 - 0s - loss: 0.0049 - val_loss: 0.0082 - 81ms/epoch - 10ms/step
# Epoch 52/100
# 8/8 - 0s - loss: 0.0047 - val_loss: 0.0080 - 79ms/epoch - 10ms/step
# Epoch 53/100
# 8/8 - 0s - loss: 0.0046 - val_loss: 0.0079 - 82ms/epoch - 10ms/step
# Epoch 54/100
# 8/8 - 0s - loss: 0.0045 - val_loss: 0.0078 - 86ms/epoch - 11ms/step
# Epoch 55/100
# 8/8 - 0s - loss: 0.0044 - val_loss: 0.0077 - 83ms/epoch - 10ms/step
# Epoch 56/100
# 8/8 - 0s - loss: 0.0043 - val_loss: 0.0077 - 83ms/epoch - 10ms/step
# Epoch 57/100
# 8/8 - 0s - loss: 0.0042 - val_loss: 0.0076 - 87ms/epoch - 11ms/step
# Epoch 58/100
# 8/8 - 0s - loss: 0.0042 - val_loss: 0.0076 - 82ms/epoch - 10ms/step
# Epoch 59/100
# 8/8 - 0s - loss: 0.0041 - val_loss: 0.0076 - 83ms/epoch - 10ms/step
# Epoch 60/100
# 8/8 - 0s - loss: 0.0040 - val_loss: 0.0076 - 85ms/epoch - 11ms/step
# Epoch 61/100
# 8/8 - 0s - loss: 0.0040 - val_loss: 0.0075 - 81ms/epoch - 10ms/step
# Epoch 62/100
# 8/8 - 0s - loss: 0.0039 - val_loss: 0.0075 - 83ms/epoch - 10ms/step
# Epoch 63/100
# 8/8 - 0s - loss: 0.0039 - val_loss: 0.0075 - 86ms/epoch - 11ms/step
# Epoch 64/100
# 8/8 - 0s - loss: 0.0039 - val_loss: 0.0075 - 82ms/epoch - 10ms/step
# Epoch 65/100
# 8/8 - 0s - loss: 0.0038 - val_loss: 0.0075 - 82ms/epoch - 10ms/step
# Epoch 66/100
# 8/8 - 0s - loss: 0.0038 - val_loss: 0.0075 - 83ms/epoch - 10ms/step
# Epoch 67/100
# 8/8 - 0s - loss: 0.0038 - val_loss: 0.0075 - 83ms/epoch - 10ms/step
# Epoch 68/100
# 8/8 - 0s - loss: 0.0038 - val_loss: 0.0075 - 81ms/epoch - 10ms/step
# Epoch 69/100
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0075 - 87ms/epoch - 11ms/step
# Epoch 70/100
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0076 - 81ms/epoch - 10ms/step
# Epoch 71/100
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0076 - 80ms/epoch - 10ms/step
# Epoch 72/100
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0076 - 83ms/epoch - 10ms/step
# Epoch 73/100
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0076 - 164ms/epoch - 20ms/step
# Epoch 74/100
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0076 - 84ms/epoch - 11ms/step
# Epoch 75/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0076 - 84ms/epoch - 11ms/step
# Epoch 76/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0076 - 85ms/epoch - 11ms/step
# Epoch 77/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0076 - 81ms/epoch - 10ms/step
# Epoch 78/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0076 - 84ms/epoch - 11ms/step
# Epoch 79/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0076 - 83ms/epoch - 10ms/step
# Epoch 80/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0077 - 85ms/epoch - 11ms/step
# Epoch 81/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0077 - 86ms/epoch - 11ms/step
# Epoch 82/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0077 - 82ms/epoch - 10ms/step
# Epoch 83/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0077 - 165ms/epoch - 21ms/step
# Epoch 84/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0077 - 167ms/epoch - 21ms/step
# Epoch 85/100
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0077 - 88ms/epoch - 11ms/step
# Epoch 86/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0077 - 85ms/epoch - 11ms/step
# Epoch 87/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0077 - 83ms/epoch - 10ms/step
# Epoch 88/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0077 - 84ms/epoch - 11ms/step
# Epoch 89/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0077 - 95ms/epoch - 12ms/step
# Epoch 90/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0077 - 82ms/epoch - 10ms/step
# Epoch 91/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 86ms/epoch - 11ms/step
# Epoch 92/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 84ms/epoch - 10ms/step
# Epoch 93/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 118ms/epoch - 15ms/step
# Epoch 94/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 87ms/epoch - 11ms/step
# Epoch 95/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 84ms/epoch - 11ms/step
# Epoch 96/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 84ms/epoch - 11ms/step
# Epoch 97/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 86ms/epoch - 11ms/step
# Epoch 98/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 93ms/epoch - 12ms/step
# Epoch 99/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 83ms/epoch - 10ms/step
# Epoch 100/100
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0078 - 84ms/epoch - 11ms/step
# 1/1 [==============================] - 1s 635ms/step
# Test RMSE for LSTM: 165.551
# Test set results:
#          date   prediction  actual
# 0  2021-12-01  2108.356943  1842.0
# 1  2022-01-01  1867.220246  2171.0
# 2  2022-02-01  2136.474512  2425.0
# 3  2022-03-01  2370.285981  2378.0
# 4  2022-04-01  2371.265359  2037.0
# 5  2022-05-01  2049.524131  1790.0
# 6  2022-06-01  1783.217829  1512.0
# 7  2022-07-01  1497.735694  1265.0
# 8  2022-08-01  1218.420746  1217.0
# 9  2022-09-01  1237.176143  1219.0
# 10 2022-10-01  1264.257870  1018.0
# 11 2022-11-01  1096.001153  1065.0
# 12 2022-12-01  1108.456776  1073.0
# 13 2023-01-01  1176.493370  1041.0
# 14 2023-02-01  1115.824728  1039.0
# 15 2023-03-01  1060.700326  1040.0
# 16 2023-04-01  1048.958516  1008.0
# 17 2023-05-01   982.603747   974.0
# 18 2023-06-01   950.764811   915.0
# 19 2023-07-01   898.876417   978.0
# 20 2023-08-01   928.046358   993.0
# 21 2023-09-01   974.732339   945.0
# 22 2023-10-01   924.465201   906.0
# 23 2023-11-01   923.475268   966.0
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# Forecasted dataframe:
#             forecasted_data
# 2023-12-01       923.475296
# 2024-01-01      1054.011952
# 2024-02-01      1099.770607
# 2024-03-01      1131.930119
# 2024-04-01      1185.046282
# 2024-05-01      1229.644049
# Specs: batch_size=18, n_months=1, RMSE=165.55108888541287
# Training model with batch_size=24, n_months=1, and test_months=24...
# Our total data have shape:  (166, 26)
# Train and test shapes are:  (142, 26) (24, 26)
# Train X,y and Test X,y are:  (142, 1, 13) (142,) (24, 1, 13) (24,)
# Epoch 1/100
# 6/6 - 3s - loss: 0.1115 - val_loss: 0.1749 - 3s/epoch - 556ms/step
# Epoch 2/100
# 6/6 - 1s - loss: 0.0683 - val_loss: 0.1213 - 515ms/epoch - 86ms/step
# Epoch 3/100
# 6/6 - 0s - loss: 0.0472 - val_loss: 0.0912 - 459ms/epoch - 76ms/step
# Epoch 4/100
# 6/6 - 0s - loss: 0.0408 - val_loss: 0.0777 - 365ms/epoch - 61ms/step
# Epoch 5/100
# 6/6 - 0s - loss: 0.0396 - val_loss: 0.0726 - 199ms/epoch - 33ms/step
# Epoch 6/100
# 6/6 - 0s - loss: 0.0381 - val_loss: 0.0713 - 76ms/epoch - 13ms/step
# Epoch 7/100
# 6/6 - 0s - loss: 0.0359 - val_loss: 0.0717 - 107ms/epoch - 18ms/step
# Epoch 8/100
# 6/6 - 0s - loss: 0.0342 - val_loss: 0.0726 - 75ms/epoch - 13ms/step
# Epoch 9/100
# 6/6 - 0s - loss: 0.0332 - val_loss: 0.0725 - 149ms/epoch - 25ms/step
# Epoch 10/100
# 6/6 - 0s - loss: 0.0326 - val_loss: 0.0710 - 64ms/epoch - 11ms/step
# Epoch 11/100
# 6/6 - 0s - loss: 0.0318 - val_loss: 0.0685 - 152ms/epoch - 25ms/step
# Epoch 12/100
# 6/6 - 0s - loss: 0.0310 - val_loss: 0.0656 - 75ms/epoch - 13ms/step
# Epoch 13/100
# 6/6 - 0s - loss: 0.0301 - val_loss: 0.0627 - 157ms/epoch - 26ms/step
# Epoch 14/100
# 6/6 - 0s - loss: 0.0291 - val_loss: 0.0603 - 96ms/epoch - 16ms/step
# Epoch 15/100
# 6/6 - 0s - loss: 0.0282 - val_loss: 0.0582 - 87ms/epoch - 14ms/step
# Epoch 16/100
# 6/6 - 0s - loss: 0.0274 - val_loss: 0.0563 - 75ms/epoch - 13ms/step
# Epoch 17/100
# 6/6 - 0s - loss: 0.0265 - val_loss: 0.0545 - 64ms/epoch - 11ms/step
# Epoch 18/100
# 6/6 - 0s - loss: 0.0257 - val_loss: 0.0528 - 63ms/epoch - 11ms/step
# Epoch 19/100
# 6/6 - 0s - loss: 0.0249 - val_loss: 0.0509 - 112ms/epoch - 19ms/step
# Epoch 20/100
# 6/6 - 0s - loss: 0.0242 - val_loss: 0.0491 - 202ms/epoch - 34ms/step
# Epoch 21/100
# 6/6 - 0s - loss: 0.0234 - val_loss: 0.0472 - 85ms/epoch - 14ms/step
# Epoch 22/100
# 6/6 - 0s - loss: 0.0226 - val_loss: 0.0453 - 83ms/epoch - 14ms/step
# Epoch 23/100
# 6/6 - 0s - loss: 0.0219 - val_loss: 0.0435 - 85ms/epoch - 14ms/step
# Epoch 24/100
# 6/6 - 0s - loss: 0.0212 - val_loss: 0.0418 - 84ms/epoch - 14ms/step
# Epoch 25/100
# 6/6 - 0s - loss: 0.0204 - val_loss: 0.0401 - 65ms/epoch - 11ms/step
# Epoch 26/100
# 6/6 - 0s - loss: 0.0197 - val_loss: 0.0384 - 60ms/epoch - 10ms/step
# Epoch 27/100
# 6/6 - 0s - loss: 0.0190 - val_loss: 0.0367 - 88ms/epoch - 15ms/step
# Epoch 28/100
# 6/6 - 0s - loss: 0.0183 - val_loss: 0.0351 - 111ms/epoch - 18ms/step
# Epoch 29/100
# 6/6 - 0s - loss: 0.0176 - val_loss: 0.0335 - 64ms/epoch - 11ms/step
# Epoch 30/100
# 6/6 - 0s - loss: 0.0169 - val_loss: 0.0319 - 74ms/epoch - 12ms/step
# Epoch 31/100
# 6/6 - 0s - loss: 0.0163 - val_loss: 0.0303 - 168ms/epoch - 28ms/step
# Epoch 32/100
# 6/6 - 0s - loss: 0.0156 - val_loss: 0.0288 - 67ms/epoch - 11ms/step
# Epoch 33/100
# 6/6 - 0s - loss: 0.0150 - val_loss: 0.0274 - 94ms/epoch - 16ms/step
# Epoch 34/100
# 6/6 - 0s - loss: 0.0144 - val_loss: 0.0259 - 66ms/epoch - 11ms/step
# Epoch 35/100
# 6/6 - 0s - loss: 0.0138 - val_loss: 0.0246 - 65ms/epoch - 11ms/step
# Epoch 36/100
# 6/6 - 0s - loss: 0.0132 - val_loss: 0.0232 - 67ms/epoch - 11ms/step
# Epoch 37/100
# 6/6 - 0s - loss: 0.0126 - val_loss: 0.0220 - 68ms/epoch - 11ms/step
# Epoch 38/100
# 6/6 - 0s - loss: 0.0120 - val_loss: 0.0208 - 61ms/epoch - 10ms/step
# Epoch 39/100
# 6/6 - 0s - loss: 0.0115 - val_loss: 0.0196 - 63ms/epoch - 10ms/step
# Epoch 40/100
# 6/6 - 0s - loss: 0.0110 - val_loss: 0.0185 - 72ms/epoch - 12ms/step
# Epoch 41/100
# 6/6 - 0s - loss: 0.0105 - val_loss: 0.0175 - 62ms/epoch - 10ms/step
# Epoch 42/100
# 6/6 - 0s - loss: 0.0100 - val_loss: 0.0165 - 61ms/epoch - 10ms/step
# Epoch 43/100
# 6/6 - 0s - loss: 0.0096 - val_loss: 0.0157 - 63ms/epoch - 11ms/step
# Epoch 44/100
# 6/6 - 0s - loss: 0.0092 - val_loss: 0.0148 - 68ms/epoch - 11ms/step
# Epoch 45/100
# 6/6 - 0s - loss: 0.0088 - val_loss: 0.0141 - 67ms/epoch - 11ms/step
# Epoch 46/100
# 6/6 - 0s - loss: 0.0084 - val_loss: 0.0134 - 62ms/epoch - 10ms/step
# Epoch 47/100
# 6/6 - 0s - loss: 0.0080 - val_loss: 0.0127 - 62ms/epoch - 10ms/step
# Epoch 48/100
# 6/6 - 0s - loss: 0.0077 - val_loss: 0.0121 - 68ms/epoch - 11ms/step
# Epoch 49/100
# 6/6 - 0s - loss: 0.0074 - val_loss: 0.0116 - 72ms/epoch - 12ms/step
# Epoch 50/100
# 6/6 - 0s - loss: 0.0071 - val_loss: 0.0111 - 63ms/epoch - 10ms/step
# Epoch 51/100
# 6/6 - 0s - loss: 0.0068 - val_loss: 0.0107 - 61ms/epoch - 10ms/step
# Epoch 52/100
# 6/6 - 0s - loss: 0.0065 - val_loss: 0.0103 - 63ms/epoch - 11ms/step
# Epoch 53/100
# 6/6 - 0s - loss: 0.0063 - val_loss: 0.0100 - 72ms/epoch - 12ms/step
# Epoch 54/100
# 6/6 - 0s - loss: 0.0061 - val_loss: 0.0097 - 62ms/epoch - 10ms/step
# Epoch 55/100
# 6/6 - 0s - loss: 0.0059 - val_loss: 0.0094 - 60ms/epoch - 10ms/step
# Epoch 56/100
# 6/6 - 0s - loss: 0.0057 - val_loss: 0.0091 - 70ms/epoch - 12ms/step
# Epoch 57/100
# 6/6 - 0s - loss: 0.0055 - val_loss: 0.0089 - 72ms/epoch - 12ms/step
# Epoch 58/100
# 6/6 - 0s - loss: 0.0053 - val_loss: 0.0087 - 62ms/epoch - 10ms/step
# Epoch 59/100
# 6/6 - 0s - loss: 0.0052 - val_loss: 0.0086 - 62ms/epoch - 10ms/step
# Epoch 60/100
# 6/6 - 0s - loss: 0.0050 - val_loss: 0.0084 - 64ms/epoch - 11ms/step
# Epoch 61/100
# 6/6 - 0s - loss: 0.0049 - val_loss: 0.0083 - 70ms/epoch - 12ms/step
# Epoch 62/100
# 6/6 - 0s - loss: 0.0048 - val_loss: 0.0082 - 63ms/epoch - 11ms/step
# Epoch 63/100
# 6/6 - 0s - loss: 0.0047 - val_loss: 0.0081 - 63ms/epoch - 11ms/step
# Epoch 64/100
# 6/6 - 0s - loss: 0.0046 - val_loss: 0.0080 - 70ms/epoch - 12ms/step
# Epoch 65/100
# 6/6 - 0s - loss: 0.0045 - val_loss: 0.0080 - 66ms/epoch - 11ms/step
# Epoch 66/100
# 6/6 - 0s - loss: 0.0044 - val_loss: 0.0079 - 62ms/epoch - 10ms/step
# Epoch 67/100
# 6/6 - 0s - loss: 0.0043 - val_loss: 0.0079 - 61ms/epoch - 10ms/step
# Epoch 68/100
# 6/6 - 0s - loss: 0.0042 - val_loss: 0.0078 - 65ms/epoch - 11ms/step
# Epoch 69/100
# 6/6 - 0s - loss: 0.0042 - val_loss: 0.0078 - 69ms/epoch - 11ms/step
# Epoch 70/100
# 6/6 - 0s - loss: 0.0041 - val_loss: 0.0078 - 64ms/epoch - 11ms/step
# Epoch 71/100
# 6/6 - 0s - loss: 0.0041 - val_loss: 0.0078 - 61ms/epoch - 10ms/step
# Epoch 72/100
# 6/6 - 0s - loss: 0.0040 - val_loss: 0.0078 - 70ms/epoch - 12ms/step
# Epoch 73/100
# 6/6 - 0s - loss: 0.0040 - val_loss: 0.0078 - 66ms/epoch - 11ms/step
# Epoch 74/100
# 6/6 - 0s - loss: 0.0039 - val_loss: 0.0078 - 63ms/epoch - 10ms/step
# Epoch 75/100
# 6/6 - 0s - loss: 0.0039 - val_loss: 0.0078 - 62ms/epoch - 10ms/step
# Epoch 76/100
# 6/6 - 0s - loss: 0.0039 - val_loss: 0.0078 - 67ms/epoch - 11ms/step
# Epoch 77/100
# 6/6 - 0s - loss: 0.0038 - val_loss: 0.0078 - 70ms/epoch - 12ms/step
# Epoch 78/100
# 6/6 - 0s - loss: 0.0038 - val_loss: 0.0078 - 62ms/epoch - 10ms/step
# Epoch 79/100
# 6/6 - 0s - loss: 0.0038 - val_loss: 0.0078 - 61ms/epoch - 10ms/step
# Epoch 80/100
# 6/6 - 0s - loss: 0.0038 - val_loss: 0.0078 - 75ms/epoch - 12ms/step
# Epoch 81/100
# 6/6 - 0s - loss: 0.0037 - val_loss: 0.0079 - 68ms/epoch - 11ms/step
# Epoch 82/100
# 6/6 - 0s - loss: 0.0037 - val_loss: 0.0079 - 63ms/epoch - 10ms/step
# Epoch 83/100
# 6/6 - 0s - loss: 0.0037 - val_loss: 0.0079 - 62ms/epoch - 10ms/step
# Epoch 84/100
# 6/6 - 0s - loss: 0.0037 - val_loss: 0.0079 - 64ms/epoch - 11ms/step
# Epoch 85/100
# 6/6 - 0s - loss: 0.0037 - val_loss: 0.0079 - 66ms/epoch - 11ms/step
# Epoch 86/100
# 6/6 - 0s - loss: 0.0037 - val_loss: 0.0080 - 62ms/epoch - 10ms/step
# Epoch 87/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0080 - 61ms/epoch - 10ms/step
# Epoch 88/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0080 - 63ms/epoch - 10ms/step
# Epoch 89/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0080 - 73ms/epoch - 12ms/step
# Epoch 90/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0080 - 61ms/epoch - 10ms/step
# Epoch 91/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0081 - 60ms/epoch - 10ms/step
# Epoch 92/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0081 - 62ms/epoch - 10ms/step
# Epoch 93/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0081 - 71ms/epoch - 12ms/step
# Epoch 94/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0081 - 63ms/epoch - 10ms/step
# Epoch 95/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0081 - 63ms/epoch - 10ms/step
# Epoch 96/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0082 - 64ms/epoch - 11ms/step
# Epoch 97/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0082 - 76ms/epoch - 13ms/step
# Epoch 98/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0082 - 63ms/epoch - 11ms/step
# Epoch 99/100
# 6/6 - 0s - loss: 0.0036 - val_loss: 0.0082 - 62ms/epoch - 10ms/step
# Epoch 100/100
# 6/6 - 0s - loss: 0.0035 - val_loss: 0.0082 - 61ms/epoch - 10ms/step
# 1/1 [==============================] - 1s 547ms/step
# Test RMSE for LSTM: 169.950
# Test set results:
#          date   prediction  actual
# 0  2021-12-01  2121.035350  1842.0
# 1  2022-01-01  1881.788267  2171.0
# 2  2022-02-01  2141.102652  2425.0
# 3  2022-03-01  2432.283228  2378.0
# 4  2022-04-01  2398.496595  2037.0
# 5  2022-05-01  2033.253146  1790.0
# 6  2022-06-01  1806.347474  1512.0
# 7  2022-07-01  1508.410554  1265.0
# 8  2022-08-01  1223.578396  1217.0
# 9  2022-09-01  1245.250815  1219.0
# 10 2022-10-01  1256.323882  1018.0
# 11 2022-11-01  1091.480690  1065.0
# 12 2022-12-01  1118.375265  1073.0
# 13 2023-01-01  1163.507456  1041.0
# 14 2023-02-01  1112.334354  1039.0
# 15 2023-03-01  1070.592902  1040.0
# 16 2023-04-01  1088.028462  1008.0
# 17 2023-05-01  1025.588327   974.0
# 18 2023-06-01   942.087829   915.0
# 19 2023-07-01   887.789750   978.0
# 20 2023-08-01   945.635951   993.0
# 21 2023-09-01   980.334022   945.0
# 22 2023-10-01   979.284273   906.0
# 23 2023-11-01   902.832045   966.0
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# Forecasted dataframe:
#             forecasted_data
# 2023-12-01       902.831905
# 2024-01-01      1051.408357
# 2024-02-01      1132.108056
# 2024-03-01      1214.840734
# 2024-04-01      1222.460568
# 2024-05-01      1187.288083
# Specs: batch_size=24, n_months=1, RMSE=169.95004616704173
# Training model with batch_size=32, n_months=1, and test_months=24...
# Our total data have shape:  (166, 26)
# Train and test shapes are:  (142, 26) (24, 26)
# Train X,y and Test X,y are:  (142, 1, 13) (142,) (24, 1, 13) (24,)
# Epoch 1/100
# 5/5 - 3s - loss: 0.0980 - val_loss: 0.1465 - 3s/epoch - 652ms/step
# Epoch 2/100
# 5/5 - 1s - loss: 0.0597 - val_loss: 0.1011 - 636ms/epoch - 127ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 0.0413 - val_loss: 0.0756 - 156ms/epoch - 31ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 0.0364 - val_loss: 0.0639 - 145ms/epoch - 29ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 0.0370 - val_loss: 0.0593 - 63ms/epoch - 13ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 0.0371 - val_loss: 0.0576 - 327ms/epoch - 65ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 0.0354 - val_loss: 0.0573 - 145ms/epoch - 29ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 0.0331 - val_loss: 0.0578 - 297ms/epoch - 59ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 0.0313 - val_loss: 0.0585 - 78ms/epoch - 16ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 0.0301 - val_loss: 0.0585 - 65ms/epoch - 13ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 0.0294 - val_loss: 0.0574 - 124ms/epoch - 25ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 0.0288 - val_loss: 0.0555 - 149ms/epoch - 30ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 0.0282 - val_loss: 0.0531 - 208ms/epoch - 42ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 0.0275 - val_loss: 0.0506 - 93ms/epoch - 19ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 0.0268 - val_loss: 0.0484 - 172ms/epoch - 34ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 0.0261 - val_loss: 0.0464 - 68ms/epoch - 14ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 0.0254 - val_loss: 0.0447 - 57ms/epoch - 11ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 0.0247 - val_loss: 0.0431 - 109ms/epoch - 22ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 0.0239 - val_loss: 0.0416 - 117ms/epoch - 23ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 0.0232 - val_loss: 0.0401 - 62ms/epoch - 12ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 0.0225 - val_loss: 0.0385 - 57ms/epoch - 11ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 0.0218 - val_loss: 0.0370 - 63ms/epoch - 13ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 0.0211 - val_loss: 0.0354 - 113ms/epoch - 23ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 0.0205 - val_loss: 0.0338 - 58ms/epoch - 12ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 0.0198 - val_loss: 0.0323 - 73ms/epoch - 15ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 0.0192 - val_loss: 0.0308 - 68ms/epoch - 14ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 0.0185 - val_loss: 0.0294 - 61ms/epoch - 12ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 0.0179 - val_loss: 0.0280 - 60ms/epoch - 12ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 0.0173 - val_loss: 0.0267 - 145ms/epoch - 29ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 0.0167 - val_loss: 0.0254 - 58ms/epoch - 12ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 0.0161 - val_loss: 0.0241 - 92ms/epoch - 18ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 0.0155 - val_loss: 0.0229 - 70ms/epoch - 14ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 0.0150 - val_loss: 0.0218 - 65ms/epoch - 13ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 0.0144 - val_loss: 0.0207 - 57ms/epoch - 11ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.0139 - val_loss: 0.0196 - 59ms/epoch - 12ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.0134 - val_loss: 0.0186 - 60ms/epoch - 12ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.0129 - val_loss: 0.0177 - 67ms/epoch - 13ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.0124 - val_loss: 0.0168 - 90ms/epoch - 18ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.0119 - val_loss: 0.0159 - 59ms/epoch - 12ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.0114 - val_loss: 0.0151 - 58ms/epoch - 12ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.0110 - val_loss: 0.0144 - 62ms/epoch - 12ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.0105 - val_loss: 0.0137 - 57ms/epoch - 11ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.0101 - val_loss: 0.0130 - 55ms/epoch - 11ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.0097 - val_loss: 0.0124 - 59ms/epoch - 12ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.0093 - val_loss: 0.0119 - 58ms/epoch - 12ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.0090 - val_loss: 0.0114 - 59ms/epoch - 12ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.0086 - val_loss: 0.0109 - 57ms/epoch - 11ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.0083 - val_loss: 0.0105 - 56ms/epoch - 11ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.0079 - val_loss: 0.0101 - 138ms/epoch - 28ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.0076 - val_loss: 0.0097 - 57ms/epoch - 11ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.0073 - val_loss: 0.0094 - 57ms/epoch - 11ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.0070 - val_loss: 0.0091 - 57ms/epoch - 11ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.0068 - val_loss: 0.0089 - 63ms/epoch - 13ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.0065 - val_loss: 0.0087 - 55ms/epoch - 11ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.0085 - 56ms/epoch - 11ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.0061 - val_loss: 0.0083 - 58ms/epoch - 12ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.0082 - 57ms/epoch - 11ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.0081 - 64ms/epoch - 13ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0080 - 57ms/epoch - 11ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.0053 - val_loss: 0.0080 - 55ms/epoch - 11ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.0079 - 56ms/epoch - 11ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.0050 - val_loss: 0.0079 - 60ms/epoch - 12ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.0049 - val_loss: 0.0079 - 57ms/epoch - 11ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.0048 - val_loss: 0.0079 - 57ms/epoch - 11ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0079 - 56ms/epoch - 11ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.0046 - val_loss: 0.0079 - 55ms/epoch - 11ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.0045 - val_loss: 0.0079 - 61ms/epoch - 12ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0079 - 64ms/epoch - 13ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.0043 - val_loss: 0.0079 - 55ms/epoch - 11ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.0043 - val_loss: 0.0080 - 58ms/epoch - 12ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.0042 - val_loss: 0.0080 - 64ms/epoch - 13ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.0042 - val_loss: 0.0081 - 56ms/epoch - 11ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0081 - 58ms/epoch - 12ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0081 - 55ms/epoch - 11ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.0040 - val_loss: 0.0082 - 60ms/epoch - 12ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.0040 - val_loss: 0.0082 - 65ms/epoch - 13ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0083 - 56ms/epoch - 11ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0083 - 56ms/epoch - 11ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0083 - 54ms/epoch - 11ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0084 - 65ms/epoch - 13ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0084 - 55ms/epoch - 11ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0084 - 58ms/epoch - 12ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0085 - 55ms/epoch - 11ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0085 - 56ms/epoch - 11ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0085 - 64ms/epoch - 13ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0085 - 56ms/epoch - 11ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0086 - 55ms/epoch - 11ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0086 - 56ms/epoch - 11ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0086 - 64ms/epoch - 13ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0086 - 59ms/epoch - 12ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0087 - 56ms/epoch - 11ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0087 - 57ms/epoch - 11ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0087 - 57ms/epoch - 11ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0087 - 64ms/epoch - 13ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0087 - 57ms/epoch - 11ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0087 - 61ms/epoch - 12ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0088 - 56ms/epoch - 11ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.0036 - val_loss: 0.0088 - 64ms/epoch - 13ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.0036 - val_loss: 0.0088 - 58ms/epoch - 12ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.0036 - val_loss: 0.0088 - 55ms/epoch - 11ms/step
# 1/1 [==============================] - 1s 618ms/step
# Test RMSE for LSTM: 175.728
# Test set results:
#          date   prediction  actual
# 0  2021-12-01  2137.995742  1842.0
# 1  2022-01-01  1915.548763  2171.0
# 2  2022-02-01  2180.283906  2425.0
# 3  2022-03-01  2428.786153  2378.0
# 4  2022-04-01  2413.152188  2037.0
# 5  2022-05-01  2065.027520  1790.0
# 6  2022-06-01  1806.708709  1512.0
# 7  2022-07-01  1526.333122  1265.0
# 8  2022-08-01  1255.179302  1217.0
# 9  2022-09-01  1274.548094  1219.0
# 10 2022-10-01  1291.951540  1018.0
# 11 2022-11-01  1117.283630  1065.0
# 12 2022-12-01  1100.436668  1073.0
# 13 2023-01-01  1219.658596  1041.0
# 14 2023-02-01  1121.541209  1039.0
# 15 2023-03-01  1044.453692  1040.0
# 16 2023-04-01  1080.834760  1008.0
# 17 2023-05-01   998.321068   974.0
# 18 2023-06-01   941.975488   915.0
# 19 2023-07-01   879.097298   978.0
# 20 2023-08-01   909.024811   993.0
# 21 2023-09-01   961.109991   945.0
# 22 2023-10-01   961.084971   906.0
# 23 2023-11-01   895.781988   966.0
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# Forecasted dataframe:
#             forecasted_data
# 2023-12-01       895.781932
# 2024-01-01      1070.480588
# 2024-02-01      1177.695867
# 2024-03-01      1352.577849
# 2024-04-01      1415.788819
# 2024-05-01      1431.806638
# Specs: batch_size=32, n_months=1, RMSE=175.72774793843038
# Training model with batch_size=36, n_months=1, and test_months=24...
# Our total data have shape:  (166, 26)
# Train and test shapes are:  (142, 26) (24, 26)
# Train X,y and Test X,y are:  (142, 1, 13) (142,) (24, 1, 13) (24,)
# Epoch 1/100
# 4/4 - 4s - loss: 0.1246 - val_loss: 0.2031 - 4s/epoch - 925ms/step
# Epoch 2/100
# 4/4 - 1s - loss: 0.0859 - val_loss: 0.1542 - 735ms/epoch - 184ms/step
# Epoch 3/100
# 4/4 - 1s - loss: 0.0605 - val_loss: 0.1192 - 543ms/epoch - 136ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 0.0467 - val_loss: 0.0967 - 216ms/epoch - 54ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 0.0413 - val_loss: 0.0839 - 196ms/epoch - 49ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 0.0404 - val_loss: 0.0774 - 264ms/epoch - 66ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 0.0404 - val_loss: 0.0745 - 326ms/epoch - 81ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 0.0395 - val_loss: 0.0734 - 217ms/epoch - 54ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 0.0379 - val_loss: 0.0736 - 123ms/epoch - 31ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 0.0361 - val_loss: 0.0746 - 66ms/epoch - 16ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 0.0349 - val_loss: 0.0757 - 146ms/epoch - 36ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 0.0341 - val_loss: 0.0764 - 94ms/epoch - 23ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.0336 - val_loss: 0.0761 - 51ms/epoch - 13ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.0331 - val_loss: 0.0749 - 51ms/epoch - 13ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.0326 - val_loss: 0.0729 - 105ms/epoch - 26ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.0319 - val_loss: 0.0705 - 52ms/epoch - 13ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.0312 - val_loss: 0.0680 - 68ms/epoch - 17ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.0305 - val_loss: 0.0656 - 49ms/epoch - 12ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.0298 - val_loss: 0.0635 - 159ms/epoch - 40ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.0291 - val_loss: 0.0617 - 53ms/epoch - 13ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.0284 - val_loss: 0.0602 - 49ms/epoch - 12ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.0277 - val_loss: 0.0588 - 55ms/epoch - 14ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.0271 - val_loss: 0.0575 - 50ms/epoch - 12ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.0264 - val_loss: 0.0561 - 49ms/epoch - 12ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.0258 - val_loss: 0.0547 - 51ms/epoch - 13ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.0252 - val_loss: 0.0533 - 48ms/epoch - 12ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.0246 - val_loss: 0.0518 - 106ms/epoch - 27ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.0240 - val_loss: 0.0502 - 171ms/epoch - 43ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.0234 - val_loss: 0.0486 - 72ms/epoch - 18ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.0228 - val_loss: 0.0471 - 94ms/epoch - 24ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.0222 - val_loss: 0.0456 - 52ms/epoch - 13ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.0216 - val_loss: 0.0442 - 50ms/epoch - 13ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.0210 - val_loss: 0.0428 - 65ms/epoch - 16ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.0204 - val_loss: 0.0414 - 50ms/epoch - 12ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.0198 - val_loss: 0.0400 - 49ms/epoch - 12ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.0193 - val_loss: 0.0387 - 54ms/epoch - 13ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.0187 - val_loss: 0.0373 - 50ms/epoch - 13ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.0182 - val_loss: 0.0360 - 68ms/epoch - 17ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.0176 - val_loss: 0.0346 - 78ms/epoch - 20ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.0171 - val_loss: 0.0334 - 50ms/epoch - 13ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.0166 - val_loss: 0.0321 - 51ms/epoch - 13ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.0161 - val_loss: 0.0309 - 57ms/epoch - 14ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.0156 - val_loss: 0.0297 - 48ms/epoch - 12ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.0151 - val_loss: 0.0285 - 52ms/epoch - 13ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.0146 - val_loss: 0.0274 - 51ms/epoch - 13ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.0141 - val_loss: 0.0263 - 52ms/epoch - 13ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.0137 - val_loss: 0.0252 - 59ms/epoch - 15ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.0132 - val_loss: 0.0242 - 53ms/epoch - 13ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.0128 - val_loss: 0.0232 - 50ms/epoch - 12ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.0124 - val_loss: 0.0223 - 48ms/epoch - 12ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.0120 - val_loss: 0.0214 - 48ms/epoch - 12ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.0116 - val_loss: 0.0205 - 55ms/epoch - 14ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.0112 - val_loss: 0.0197 - 47ms/epoch - 12ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.0108 - val_loss: 0.0189 - 49ms/epoch - 12ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.0105 - val_loss: 0.0181 - 48ms/epoch - 12ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.0101 - val_loss: 0.0174 - 48ms/epoch - 12ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.0098 - val_loss: 0.0167 - 63ms/epoch - 16ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.0095 - val_loss: 0.0160 - 51ms/epoch - 13ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.0091 - val_loss: 0.0154 - 49ms/epoch - 12ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.0089 - val_loss: 0.0148 - 48ms/epoch - 12ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.0086 - val_loss: 0.0143 - 47ms/epoch - 12ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.0083 - val_loss: 0.0138 - 59ms/epoch - 15ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.0080 - val_loss: 0.0133 - 49ms/epoch - 12ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.0078 - val_loss: 0.0128 - 49ms/epoch - 12ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.0075 - val_loss: 0.0124 - 49ms/epoch - 12ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.0073 - val_loss: 0.0120 - 50ms/epoch - 12ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.0071 - val_loss: 0.0116 - 52ms/epoch - 13ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.0069 - val_loss: 0.0113 - 52ms/epoch - 13ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.0067 - val_loss: 0.0109 - 51ms/epoch - 13ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.0065 - val_loss: 0.0106 - 49ms/epoch - 12ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.0063 - val_loss: 0.0104 - 48ms/epoch - 12ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.0062 - val_loss: 0.0101 - 50ms/epoch - 13ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 0.0060 - val_loss: 0.0099 - 57ms/epoch - 14ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.0058 - val_loss: 0.0096 - 48ms/epoch - 12ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 0.0057 - val_loss: 0.0094 - 50ms/epoch - 13ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 0.0056 - val_loss: 0.0092 - 49ms/epoch - 12ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 0.0054 - val_loss: 0.0091 - 52ms/epoch - 13ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 0.0053 - val_loss: 0.0089 - 55ms/epoch - 14ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 0.0052 - val_loss: 0.0088 - 51ms/epoch - 13ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 0.0051 - val_loss: 0.0086 - 49ms/epoch - 12ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 0.0050 - val_loss: 0.0085 - 50ms/epoch - 13ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 0.0049 - val_loss: 0.0084 - 48ms/epoch - 12ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 0.0048 - val_loss: 0.0083 - 58ms/epoch - 14ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 0.0047 - val_loss: 0.0082 - 59ms/epoch - 15ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 0.0046 - val_loss: 0.0082 - 48ms/epoch - 12ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 0.0046 - val_loss: 0.0081 - 48ms/epoch - 12ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 0.0045 - val_loss: 0.0081 - 49ms/epoch - 12ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 0.0044 - val_loss: 0.0080 - 52ms/epoch - 13ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 0.0044 - val_loss: 0.0080 - 50ms/epoch - 12ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 0.0043 - val_loss: 0.0079 - 48ms/epoch - 12ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 0.0043 - val_loss: 0.0079 - 49ms/epoch - 12ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 0.0042 - val_loss: 0.0079 - 50ms/epoch - 12ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 0.0042 - val_loss: 0.0079 - 53ms/epoch - 13ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 0.0042 - val_loss: 0.0079 - 49ms/epoch - 12ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 0.0041 - val_loss: 0.0078 - 54ms/epoch - 14ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 0.0041 - val_loss: 0.0078 - 52ms/epoch - 13ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 0.0040 - val_loss: 0.0078 - 48ms/epoch - 12ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 0.0040 - val_loss: 0.0078 - 56ms/epoch - 14ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 0.0040 - val_loss: 0.0078 - 48ms/epoch - 12ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 0.0040 - val_loss: 0.0078 - 48ms/epoch - 12ms/step
# 1/1 [==============================] - 1s 553ms/step
# Test RMSE for LSTM: 165.927
# Test set results:
#          date   prediction  actual
# 0  2021-12-01  2056.217141  1842.0
# 1  2022-01-01  1827.304013  2171.0
# 2  2022-02-01  2069.172339  2425.0
# 3  2022-03-01  2349.607126  2378.0
# 4  2022-04-01  2291.092210  2037.0
# 5  2022-05-01  1971.997022  1790.0
# 6  2022-06-01  1746.815649  1512.0
# 7  2022-07-01  1526.367190  1265.0
# 8  2022-08-01  1258.955178  1217.0
# 9  2022-09-01  1277.244678  1219.0
# 10 2022-10-01  1251.509763  1018.0
# 11 2022-11-01  1139.014132  1065.0
# 12 2022-12-01  1115.328225  1073.0
# 13 2023-01-01  1211.128973  1041.0
# 14 2023-02-01  1125.046047  1039.0
# 15 2023-03-01  1072.770978  1040.0
# 16 2023-04-01  1112.225113  1008.0
# 17 2023-05-01  1025.760232   974.0
# 18 2023-06-01   941.127161   915.0
# 19 2023-07-01   910.322587   978.0
# 20 2023-08-01   974.935799   993.0
# 21 2023-09-01  1007.919930   945.0
# 22 2023-10-01   984.709471   906.0
# 23 2023-11-01   845.443111   966.0
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# Forecasted dataframe:
#             forecasted_data
# 2023-12-01       845.443111
# 2024-01-01      1025.754368
# 2024-02-01      1151.986643
# 2024-03-01      1296.943820
# 2024-04-01      1299.659561
# 2024-05-01      1249.113929
# Specs: batch_size=36, n_months=1, RMSE=165.92701443455195
