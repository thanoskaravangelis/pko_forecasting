# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import pickle
import IPython
import IPython.display
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from functions.naming import rename_columns

# %%
# Load the data
df = pd.read_excel("/Users/athanasioskaravangelis/Desktop/RSM BAM/Workshop/pko_forecasting/data/PKO_Initial_Dataset.xlsx")
#rename columns
df = rename_columns(df)
# select only the values after 2010-01-01
df['date'] = pd.to_datetime(df['date'], format='%b-%y')
df = df[df['date'] > '2009-12-02']
#make date the index
df.set_index('date', inplace=True)

# %%
# Specify columns to exclude
exclude_columns = [
    'indonesia_disaster', 'malaysia_disaster', 'jet_fuel_us', 'jet_fuel_europe', 'soybean_oil_zlz2',
    'tallow_fob_us_gulf', 'palm_olein_fob_malaysia',
    'palm_stearin_cif_rotterdam', 'fatty_alcohol_c12_14_fob_asia', 'fatty_alcohol_c16_18_fob_asia',
    'fatty_alcohol_c12_14_fd_nwe', 'jet_fuel_us_usd_mt', 'rspo', 'bio_ethanol', 'cpopc_mal_ind_2015', 'mspo_certification', 'ispo_certification',
    'export_tarrifs_indonesia', 'palm_oil_cif_nwe'
]

# Filter the dataset to exclude specified columns
df_filtered = df.drop(columns=exclude_columns)

# Update NUM_FEATURES based on the filtered dataset
num_features = df_filtered.shape[1]
num_features

# fill nas with average values
df = df_filtered.fillna(df_filtered.mean())

target_column = 'pko_fob_malaysia'

data = df.copy()

# make the target column the first column in the order
target_column_index = data.columns.get_loc(target_column)
#data = data[[data.columns[target_column_index]] + [c for c in data if c != data.columns[target_column_index]]]

# create a custom order for my dataframe columns
# the order is : 'pko_cif_rotterdam', 'pko_monthly_stocks_malaysia', 'pko_monthly_stocks_indonesia', 'Temperaturemax_Indonesia'
# Temperaturemin_Malaysia, Temperaturemin_Indonesia, Temperaturemax_Malaysia, Precipitation_Indonesia, Precipitation_Malaysia
# Humidex_Indonesia, Humidex_Malaysia and then the rist of the rows
data = data[['pko_fob_malaysia','pko_monthly_stocks_malaysia', 'pko_monthly_stocks_indonesia', 'Temperaturemax_Indonesia',
                'Temperaturemin_Malaysia', 'Temperaturemin_Indonesia', 'Temperaturemax_Malaysia', 'Precipitation_Indonesia',
                'Precipitation_Malaysia', 'Humidex_Indonesia', 'Humidex_Malaysia'] + [c for c in data if c not in ['pko_fob_malaysia', 'pko_monthly_stocks_malaysia', 'pko_monthly_stocks_indonesia', 'Temperaturemax_Indonesia',
                'Temperaturemin_Malaysia', 'Temperaturemin_Indonesia', 'Temperaturemax_Malaysia', 'Precipitation_Indonesia',
                'Precipitation_Malaysia', 'Humidex_Indonesia', 'Humidex_Malaysia']]]

# Normalize the data
# Note: We should normalize the features but not the target variable
feature_columns = [col for col in data.columns if col != target_column and col != 'Date']

# Handling non-numeric values (e.g., replacing commas in numbers)
data[feature_columns] = data[feature_columns].replace(',', '', regex=True).astype(float)

# Using MinMaxScaler for normalization
#scaler = MinMaxScaler()
#data[feature_columns] = scaler.fit_transform(data[feature_columns])

data.head()
# Out:
#             pko_fob_malaysia  pko_monthly_stocks_malaysia  \
# date
# 2010-01-01             905.0                   347.569305
# 2010-02-01             913.0                   347.569305
# 2010-03-01            1062.0                   347.569305
# 2010-04-01            1073.0                   347.569305
# 2010-05-01            1074.0                   347.569305
#
#             pko_monthly_stocks_indonesia  Temperaturemax_Indonesia  \
# date
# 2010-01-01                    278.311167                  30.71202
# 2010-02-01                    278.311167                  31.22701
# 2010-03-01                    278.311167                  31.30822
# 2010-04-01                    278.311167                  31.53292
# 2010-05-01                    278.311167                  31.51028
#
#             Temperaturemin_Malaysia  Temperaturemin_Indonesia  \
# date
# 2010-01-01                 22.47141                  22.33558
# 2010-02-01                 22.48973                  22.71100
# 2010-03-01                 23.15041                  22.81132
# 2010-04-01                 23.68263                  23.15416
# 2010-05-01                 23.89869                  23.38245
#
#             Temperaturemax_Malaysia  Precipitation_Indonesia  \
# date
# 2010-01-01                 31.12185                 0.418410
# 2010-02-01                 32.42118                 0.347598
# 2010-03-01                 33.46994                 0.429777
# 2010-04-01                 32.85302                 0.412347
# 2010-05-01                 32.93819                 0.402333
#
#             Precipitation_Malaysia  Humidex_Indonesia  ...  \
# date                                                   ...
# 2010-01-01                0.361239           35.65479  ...
# 2010-02-01                0.176073           36.78451  ...
# 2010-03-01                0.244998           36.81526  ...
# 2010-04-01                0.294569           37.50045  ...
# 2010-05-01                0.315503           37.76451  ...
#
#             palm_oil_production_malaysia  pko_production_malaysia  \
# date
# 2010-01-01                   1586.233389               185.118824
# 2010-02-01                   1586.233389               185.118824
# 2010-03-01                   1586.233389               185.118824
# 2010-04-01                   1586.233389               185.118824
# 2010-05-01                   1586.233389               185.118824
#
#             pko_domestic_consumption_indonesia  \
# date
# 2010-01-01                          225.469878
# 2010-02-01                          225.469878
# 2010-03-01                          225.469878
# 2010-04-01                          225.469878
# 2010-05-01                          225.469878
#
#             pko_domestic_consumption_malaysia  pko_exports_indonesia  \
# date
# 2010-01-01                         108.663799              87.660354
# 2010-02-01                         108.663799              87.660354
# 2010-03-01                         108.663799              87.660354
# 2010-04-01                         108.663799              87.660354
# 2010-05-01                         108.663799              87.660354
#
#             pko_exports_malaysia  pko_total_supply_indonesia  \
# date
# 2010-01-01            125.476206                  233.418248
# 2010-02-01            125.476206                  233.418248
# 2010-03-01            125.476206                  233.418248
# 2010-04-01            125.476206                  233.418248
# 2010-05-01            125.476206                  233.418248
#
#             pko_total_supply_malaysia  pmi_indonesia  pmi_malaysia
# date
# 2010-01-01                 395.552877         49.845     48.462617
# 2010-02-01                 395.552877         49.845     48.462617
# 2010-03-01                 395.552877         49.845     48.462617
# 2010-04-01                 395.552877         49.845     48.462617
# 2010-05-01                 395.552877         49.845     48.462617
#
# [5 rows x 33 columns]

# %%
data.shape
# Out:
# (167, 33)

# %%
data.columns
# Out:
# Index(['pko_fob_malaysia', 'pko_monthly_stocks_malaysia',
#        'pko_monthly_stocks_indonesia', 'Temperaturemax_Indonesia',
#        'Temperaturemin_Malaysia', 'Temperaturemin_Indonesia',
#        'Temperaturemax_Malaysia', 'Precipitation_Indonesia',
#        'Precipitation_Malaysia', 'Humidex_Indonesia', 'Humidex_Malaysia',
#        'ONI', 'pko_cif_rotterdam', 'coconut_cif_rotterdam', 'ukraine_war',
#        'malaysia_harvest', 'indonesia_harvest', 'myr_usd_rate', 'idr_usd_rate',
#        'palm_oil_harvest_area_indonesia', 'palm_oil_production_indonesia',
#        'pko_production_indonesia', 'palm_oil_harvest_area_malaysia',
#        'palm_oil_production_malaysia', 'pko_production_malaysia',
#        'pko_domestic_consumption_indonesia',
#        'pko_domestic_consumption_malaysia', 'pko_exports_indonesia',
#        'pko_exports_malaysia', 'pko_total_supply_indonesia',
#        'pko_total_supply_malaysia', 'pmi_indonesia', 'pmi_malaysia'],
#       dtype='object')

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# convert series to 
def series_to_supervised(data, n_feat, n_in=1, n_out=1):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	# select only first 11 from df
	#df_custom = df.iloc[:, 0:11]
	# put the rest of the columns in df_rest
	df_rest = df.iloc[:, 11:]
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_feat)]
	# put it all together with df_rest
	#cols.append(df_rest)
	# append the rest of the column names
	#names += df_rest.columns.tolist()
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_feat)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_feat)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	agg.dropna(inplace=True)
	return agg

# %%
# Our best model up until now: n_months = 6, n_features = 12, n_train_months = 149
n_features = 11
values = data.values
# keep only the first 11 columns
values = values[:, 0:n_features]
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# specify the number of lag months
n_months = 6
n_rest = 21
# frame as 
reframed = series_to_supervised(scaled, n_features, n_months, 1)
print(reframed.shape)
# Out:
# (161, 77)

# %%
values=reframed.values
n_train_months = 149
train = values[:n_train_months, :]
test = values[n_train_months:, :]

# %%
train.shape, test.shape
# Out:
# ((149, 77), (12, 77))

# %%
# split into input and outputs
n_obs = n_months * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_months, n_features))
test_X = test_X.reshape((test_X.shape[0], n_months, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (149, 6, 11) (149,) (12, 6, 11) (12,)

# %%
train_y
# Out:
# array([0.29507765, 0.34193209, 0.37773098, 0.48775994, 0.57304554,
#        0.73308765, 0.89312977, 0.97367728, 0.78520663, 0.71150303,
#        0.73887865, 0.67780995, 0.45775204, 0.45090813, 0.41142406,
#        0.22295341, 0.34351145, 0.4224796 , 0.45143459, 0.41458278,
#        0.47986312, 0.4951303 , 0.43037641, 0.31350355, 0.31666228,
#        0.23400895, 0.20505396, 0.11976836, 0.118189  , 0.09133983,
#        0.11713609, 0.13924717, 0.10923927, 0.12819163, 0.13029745,
#        0.14977626, 0.14767044, 0.14082653, 0.17294025, 0.17294025,
#        0.2334825 , 0.30823901, 0.38246907, 0.32350619, 0.35983153,
#        0.44722295, 0.38826007, 0.36614899, 0.31666228, 0.16820216,
#        0.18873388, 0.19978942, 0.20979205, 0.20294814, 0.30192156,
#        0.30192156, 0.26822848, 0.22716504, 0.21663596, 0.18978679,
#        0.16451698, 0.10818636, 0.14082653, 0.18873388, 0.16135825,
#        0.17136088, 0.19083969, 0.25927876, 0.25822585, 0.41247697,
#        0.36404317, 0.42405896, 0.38141616, 0.49776257, 0.49618321,
#        0.42932351, 0.57409845, 0.62358515, 0.66464859, 0.56567518,
#        0.40300079, 0.26612266, 0.26138457, 0.25717294, 0.23664122,
#        0.30508028, 0.41932087, 0.43879968, 0.44037905, 0.4340616 ,
#        0.39563043, 0.35693604, 0.3682548 , 0.28138984, 0.24085286,
#        0.18926033, 0.15767307, 0.19005001, 0.18267965, 0.13029745,
#        0.15767307, 0.09239273, 0.14187944, 0.12161095, 0.0581732 ,
#        0.04869703, 0.02079495, 0.04711766, 0.03132403, 0.05764675,
#        0.08923401, 0.        , 0.06291129, 0.17241379, 0.30508028,
#        0.15767307, 0.12082127, 0.09660437, 0.04711766, 0.04711766,
#        0.05764675, 0.10502764, 0.12871808, 0.14898658, 0.2732298 ,
#        0.32508555, 0.46038431, 0.43142932, 0.44722295, 0.44722295,
#        0.49986839, 0.46301658, 0.39194525, 0.42616478, 0.42616478,
#        0.51566202, 0.86838642, 0.83153461, 0.85522506, 0.99473546,
#        1.        , 0.8546986 , 0.72097921, 0.6530666 , 0.60831798,
#        0.35772572, 0.34824954, 0.27875757, 0.21558305])

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# 5/5 - 5s - loss: 0.0546 - val_loss: 0.0336 - 5s/epoch - 1s/step
# Epoch 2/100
# 5/5 - 0s - loss: 0.0448 - val_loss: 0.0330 - 381ms/epoch - 76ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 0.0373 - val_loss: 0.0178 - 265ms/epoch - 53ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 0.0324 - val_loss: 0.0126 - 155ms/epoch - 31ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 0.0294 - val_loss: 0.0151 - 99ms/epoch - 20ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 0.0268 - val_loss: 0.0184 - 89ms/epoch - 18ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 0.0247 - val_loss: 0.0171 - 130ms/epoch - 26ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 0.0222 - val_loss: 0.0135 - 388ms/epoch - 78ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 0.0203 - val_loss: 0.0123 - 102ms/epoch - 20ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 0.0189 - val_loss: 0.0134 - 229ms/epoch - 46ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 0.0180 - val_loss: 0.0137 - 221ms/epoch - 44ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 0.0174 - val_loss: 0.0127 - 166ms/epoch - 33ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 0.0169 - val_loss: 0.0124 - 67ms/epoch - 13ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 0.0165 - val_loss: 0.0128 - 101ms/epoch - 20ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 0.0162 - val_loss: 0.0127 - 145ms/epoch - 29ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 0.0159 - val_loss: 0.0122 - 160ms/epoch - 32ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 0.0156 - val_loss: 0.0121 - 107ms/epoch - 21ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 0.0153 - val_loss: 0.0120 - 104ms/epoch - 21ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 0.0150 - val_loss: 0.0117 - 82ms/epoch - 16ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 0.0147 - val_loss: 0.0116 - 110ms/epoch - 22ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 0.0145 - val_loss: 0.0115 - 105ms/epoch - 21ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 0.0142 - val_loss: 0.0114 - 76ms/epoch - 15ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 0.0139 - val_loss: 0.0113 - 62ms/epoch - 12ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 0.0137 - val_loss: 0.0112 - 63ms/epoch - 13ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 0.0134 - val_loss: 0.0112 - 79ms/epoch - 16ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 0.0132 - val_loss: 0.0111 - 83ms/epoch - 17ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 0.0129 - val_loss: 0.0111 - 87ms/epoch - 17ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 0.0127 - val_loss: 0.0110 - 78ms/epoch - 16ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 0.0124 - val_loss: 0.0109 - 58ms/epoch - 12ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 0.0122 - val_loss: 0.0109 - 58ms/epoch - 12ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 0.0120 - val_loss: 0.0108 - 61ms/epoch - 12ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 0.0117 - val_loss: 0.0108 - 69ms/epoch - 14ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 0.0115 - val_loss: 0.0107 - 60ms/epoch - 12ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 0.0112 - val_loss: 0.0106 - 61ms/epoch - 12ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.0110 - val_loss: 0.0106 - 130ms/epoch - 26ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.0107 - val_loss: 0.0105 - 79ms/epoch - 16ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.0105 - val_loss: 0.0105 - 71ms/epoch - 14ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.0103 - val_loss: 0.0104 - 129ms/epoch - 26ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.0100 - val_loss: 0.0104 - 67ms/epoch - 13ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.0098 - val_loss: 0.0103 - 82ms/epoch - 16ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.0095 - val_loss: 0.0103 - 70ms/epoch - 14ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.0093 - val_loss: 0.0102 - 66ms/epoch - 13ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.0090 - val_loss: 0.0102 - 59ms/epoch - 12ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.0088 - val_loss: 0.0101 - 175ms/epoch - 35ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.0086 - val_loss: 0.0100 - 98ms/epoch - 20ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.0083 - val_loss: 0.0099 - 63ms/epoch - 13ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.0081 - val_loss: 0.0098 - 72ms/epoch - 14ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.0079 - val_loss: 0.0097 - 64ms/epoch - 13ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.0077 - val_loss: 0.0096 - 66ms/epoch - 13ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.0075 - val_loss: 0.0094 - 64ms/epoch - 13ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.0073 - val_loss: 0.0092 - 69ms/epoch - 14ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.0071 - val_loss: 0.0090 - 70ms/epoch - 14ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.0069 - val_loss: 0.0088 - 63ms/epoch - 13ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.0085 - 59ms/epoch - 12ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.0082 - 65ms/epoch - 13ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.0064 - val_loss: 0.0079 - 63ms/epoch - 13ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.0076 - 68ms/epoch - 14ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0074 - 57ms/epoch - 11ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.0071 - 75ms/epoch - 15ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.0068 - 63ms/epoch - 13ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.0058 - val_loss: 0.0065 - 62ms/epoch - 12ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.0063 - 58ms/epoch - 12ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0060 - 73ms/epoch - 15ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0058 - 63ms/epoch - 13ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.0054 - val_loss: 0.0056 - 60ms/epoch - 12ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.0053 - val_loss: 0.0055 - 59ms/epoch - 12ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.0053 - 64ms/epoch - 13ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.0051 - 59ms/epoch - 12ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.0051 - val_loss: 0.0050 - 62ms/epoch - 12ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.0050 - val_loss: 0.0049 - 57ms/epoch - 11ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.0050 - val_loss: 0.0048 - 82ms/epoch - 16ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.0049 - val_loss: 0.0047 - 67ms/epoch - 13ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.0048 - val_loss: 0.0046 - 63ms/epoch - 13ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.0048 - val_loss: 0.0046 - 69ms/epoch - 14ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0045 - 70ms/epoch - 14ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0045 - 60ms/epoch - 12ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.0046 - val_loss: 0.0044 - 58ms/epoch - 12ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.0046 - val_loss: 0.0044 - 61ms/epoch - 12ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.0045 - val_loss: 0.0044 - 65ms/epoch - 13ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.0045 - val_loss: 0.0043 - 59ms/epoch - 12ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0043 - 64ms/epoch - 13ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0043 - 58ms/epoch - 12ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0043 - 68ms/epoch - 14ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.0043 - val_loss: 0.0043 - 61ms/epoch - 12ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.0043 - val_loss: 0.0043 - 58ms/epoch - 12ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.0042 - val_loss: 0.0043 - 57ms/epoch - 11ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.0042 - val_loss: 0.0043 - 56ms/epoch - 11ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.0042 - val_loss: 0.0043 - 61ms/epoch - 12ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0043 - 58ms/epoch - 12ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0044 - 57ms/epoch - 11ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0044 - 56ms/epoch - 11ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.0040 - val_loss: 0.0044 - 57ms/epoch - 11ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.0040 - val_loss: 0.0044 - 61ms/epoch - 12ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.0040 - val_loss: 0.0044 - 57ms/epoch - 11ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0044 - 59ms/epoch - 12ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0045 - 57ms/epoch - 11ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0046 - 69ms/epoch - 14ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0047 - 59ms/epoch - 12ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0045 - 64ms/epoch - 13ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0041 - 58ms/epoch - 12ms/step

# %%
from keras.layers import GRU
# design network
model2 = Sequential()
model2.add(GRU(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model2.add(Dense(1))
model2.compile(loss='mean_squared_error', optimizer='adam')
# fit network
history = model2.fit(train_X, train_y, epochs=100, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# 5/5 - 3s - loss: 0.0923 - val_loss: 0.0100 - 3s/epoch - 623ms/step
# Epoch 2/100
# 5/5 - 0s - loss: 0.0501 - val_loss: 0.0472 - 328ms/epoch - 66ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 0.0522 - val_loss: 0.0483 - 136ms/epoch - 27ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 0.0459 - val_loss: 0.0283 - 230ms/epoch - 46ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 0.0398 - val_loss: 0.0157 - 207ms/epoch - 41ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 0.0377 - val_loss: 0.0117 - 104ms/epoch - 21ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 0.0357 - val_loss: 0.0146 - 141ms/epoch - 28ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 0.0332 - val_loss: 0.0198 - 88ms/epoch - 18ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 0.0314 - val_loss: 0.0211 - 120ms/epoch - 24ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 0.0294 - val_loss: 0.0182 - 100ms/epoch - 20ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 0.0273 - val_loss: 0.0146 - 130ms/epoch - 26ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 0.0254 - val_loss: 0.0117 - 93ms/epoch - 19ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 0.0239 - val_loss: 0.0121 - 134ms/epoch - 27ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 0.0225 - val_loss: 0.0134 - 131ms/epoch - 26ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 0.0212 - val_loss: 0.0133 - 67ms/epoch - 13ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 0.0200 - val_loss: 0.0126 - 72ms/epoch - 14ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 0.0188 - val_loss: 0.0115 - 82ms/epoch - 16ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 0.0176 - val_loss: 0.0106 - 123ms/epoch - 25ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 0.0166 - val_loss: 0.0097 - 179ms/epoch - 36ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 0.0157 - val_loss: 0.0086 - 67ms/epoch - 13ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 0.0149 - val_loss: 0.0088 - 83ms/epoch - 17ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 0.0142 - val_loss: 0.0092 - 121ms/epoch - 24ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 0.0136 - val_loss: 0.0087 - 64ms/epoch - 13ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 0.0130 - val_loss: 0.0072 - 58ms/epoch - 12ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 0.0125 - val_loss: 0.0064 - 62ms/epoch - 12ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 0.0121 - val_loss: 0.0065 - 56ms/epoch - 11ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 0.0117 - val_loss: 0.0068 - 55ms/epoch - 11ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 0.0113 - val_loss: 0.0068 - 55ms/epoch - 11ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 0.0110 - val_loss: 0.0063 - 55ms/epoch - 11ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 0.0107 - val_loss: 0.0058 - 56ms/epoch - 11ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 0.0104 - val_loss: 0.0058 - 63ms/epoch - 13ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 0.0101 - val_loss: 0.0063 - 54ms/epoch - 11ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 0.0099 - val_loss: 0.0063 - 52ms/epoch - 10ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 0.0096 - val_loss: 0.0054 - 63ms/epoch - 13ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.0093 - val_loss: 0.0045 - 58ms/epoch - 12ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.0091 - val_loss: 0.0046 - 72ms/epoch - 14ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.0089 - val_loss: 0.0049 - 53ms/epoch - 11ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.0087 - val_loss: 0.0050 - 57ms/epoch - 11ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.0086 - val_loss: 0.0045 - 54ms/epoch - 11ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.0084 - val_loss: 0.0040 - 60ms/epoch - 12ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.0082 - val_loss: 0.0040 - 54ms/epoch - 11ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.0081 - val_loss: 0.0041 - 53ms/epoch - 11ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.0080 - val_loss: 0.0039 - 55ms/epoch - 11ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.0078 - val_loss: 0.0036 - 54ms/epoch - 11ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.0077 - val_loss: 0.0036 - 54ms/epoch - 11ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.0076 - val_loss: 0.0034 - 53ms/epoch - 11ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.0075 - val_loss: 0.0035 - 59ms/epoch - 12ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.0074 - val_loss: 0.0035 - 57ms/epoch - 11ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.0074 - val_loss: 0.0033 - 53ms/epoch - 11ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.0073 - val_loss: 0.0033 - 52ms/epoch - 10ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.0072 - val_loss: 0.0033 - 53ms/epoch - 11ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.0071 - val_loss: 0.0031 - 57ms/epoch - 11ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.0070 - val_loss: 0.0031 - 56ms/epoch - 11ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.0070 - val_loss: 0.0032 - 52ms/epoch - 10ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.0069 - val_loss: 0.0032 - 52ms/epoch - 10ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.0068 - val_loss: 0.0031 - 54ms/epoch - 11ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.0068 - val_loss: 0.0029 - 57ms/epoch - 11ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.0031 - 52ms/epoch - 10ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.0029 - 55ms/epoch - 11ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.0065 - val_loss: 0.0030 - 53ms/epoch - 11ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.0065 - val_loss: 0.0030 - 59ms/epoch - 12ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.0064 - val_loss: 0.0030 - 55ms/epoch - 11ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.0064 - val_loss: 0.0030 - 56ms/epoch - 11ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.0064 - val_loss: 0.0032 - 54ms/epoch - 11ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.0032 - 52ms/epoch - 10ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.0030 - 56ms/epoch - 11ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0029 - 54ms/epoch - 11ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0030 - 53ms/epoch - 11ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0030 - 57ms/epoch - 11ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.0061 - val_loss: 0.0030 - 56ms/epoch - 11ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.0061 - val_loss: 0.0030 - 56ms/epoch - 11ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.0061 - val_loss: 0.0030 - 53ms/epoch - 11ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.0030 - 55ms/epoch - 11ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.0030 - 61ms/epoch - 12ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.0031 - 69ms/epoch - 14ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.0030 - 65ms/epoch - 13ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.0031 - 160ms/epoch - 32ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.0031 - 59ms/epoch - 12ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.0031 - 55ms/epoch - 11ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.0058 - val_loss: 0.0031 - 54ms/epoch - 11ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.0058 - val_loss: 0.0031 - 58ms/epoch - 12ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.0058 - val_loss: 0.0032 - 55ms/epoch - 11ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.0058 - val_loss: 0.0032 - 55ms/epoch - 11ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.0032 - 60ms/epoch - 12ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.0032 - 51ms/epoch - 10ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.0033 - 57ms/epoch - 11ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.0032 - 60ms/epoch - 12ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0032 - 57ms/epoch - 11ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0032 - 54ms/epoch - 11ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0032 - 52ms/epoch - 10ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0032 - 57ms/epoch - 11ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0033 - 54ms/epoch - 11ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0033 - 52ms/epoch - 10ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0032 - 55ms/epoch - 11ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0032 - 54ms/epoch - 11ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0034 - 57ms/epoch - 11ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0032 - 113ms/epoch - 23ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.0054 - val_loss: 0.0032 - 59ms/epoch - 12ms/step

# %%
test_X.shape
# Out:
# (12, 6, 11)

# %%
# what input shape does the model expect?
model.input_shape
# Out:
# (None, 6, 11)

# %%
test_X_reshaped = test_X.reshape((test_X.shape[0], n_months, n_features))
yhat = model.predict(test_X_reshaped)
yhat
# Out:
# 1/1 [==============================] - 1s 642ms/step
# array([[0.28459552],
#        [0.32001683],
#        [0.34270203],
#        [0.28972533],
#        [0.24036947],
#        [0.18696406],
#        [0.14369828],
#        [0.13951094],
#        [0.15092063],
#        [0.17968413],
#        [0.22378667],
#        [0.25375837]], dtype=float32)

# %%
test_X.shape
# Out:
# (12, 6, 11)

# %%
test_y.shape
# Out:
# (12,)

# %%
test_X = test_X.reshape((test_X.shape[0], n_months*n_features))
test_X.shape
# Out:
# (12, 66)

# %%
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -((n_features-1)):]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -(n_features-1):]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate 
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test : %.3f' % rmse)
# Out:
# Test : 121.514

# %%
inv_yhat
# Out:
# array([1111.08918892, 1178.37197079, 1221.46250814, 1120.83327089,
#        1027.08180623,  925.63824116,  843.45487353,  835.50103905,
#         857.17373574,  911.81000938,  995.58277395, 1052.51402548])

# %%
inv_y
# Out:
# array([1040. , 1017. ,  983. ,  982. ,  994.5,  945. ,  874. ,  945. ,
#         985. ,  905. ,  890. ,  885. ])

# %%
# plot the actual and predicted values for the test data , x-axis should be date
plt.figure(figsize=(15, 5))
plt.plot(data.index[-(test_y.shape[0]):], inv_y, label='Actual')
plt.plot(data.index[-(test_y.shape[0]):], inv_yhat, label='Predicted')
plt.legend()
plt.show()

# %%
dates = data.index[n_train_months+2:]
dates
# Out:
# DatetimeIndex(['2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
#                '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
#                '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01',
#                '2023-08-01', '2023-09-01', '2023-10-01', '2023-11-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
# create a dataframe with the dates, inv_yhat and inv_y
dates = data.index[n_train_months+6:]
df_results = pd.DataFrame({'date': dates, 'prediction': inv_yhat, 'actual': inv_y})
df_results
# Out:
#          date   prediction  actual
# 0  2022-12-01  1111.089189  1040.0
# 1  2023-01-01  1178.371971  1017.0
# 2  2023-02-01  1221.462508   983.0
# 3  2023-03-01  1120.833271   982.0
# 4  2023-04-01  1027.081806   994.5
# 5  2023-05-01   925.638241   945.0
# 6  2023-06-01   843.454874   874.0
# 7  2023-07-01   835.501039   945.0
# 8  2023-08-01   857.173736   985.0
# 9  2023-09-01   911.810009   905.0
# 10 2023-10-01   995.582774   890.0
# 11 2023-11-01  1052.514025   885.0

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import timedelta

# Assuming df_results is your DataFrame with 'date', 'prediction', and 'actual' columns
plt.figure(figsize=(15, 5))
plt.ylim(0, 1500)

# Convert dates to matplotlib date format
dates = mdates.date2num(df_results['date'])

# Width of a bar
bar_width = 10  # You might need to adjust this based on your date scale

# Plotting
# GIVE ME LIGHT GRAY COLOR FOR THE FIRST BAR
plt.bar(dates - bar_width/2, df_results['actual'], width=bar_width, color='#929292', align='center', label='Actual')
plt.bar(dates + bar_width/2, df_results['prediction'], width=bar_width, color='#A20000', align='center', label='Prediction')

# Formatting dates on the x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gcf().autofmt_xdate()  #
#         0.27101654, 0.75226882, 0.94227527, 0.15977889, 0.51029103,
#         0.31714182, 0.33563136, 0.86230684, 0.54264811, 0.72633904,
#         0.33767876, 0.29770847, 0.61317331, 0.80273022, 0.19715715,
#         0.52079172, 0.32385316, 0.16083629, 0.79673065, 0.26951016,
#         0.56455071, 0.32720538, 0.36677752, 0.32985575, 0.73692723,
#         0.21821532, 0.55609337, 0.34641562, 0.26951506, 0.73667524,
#         0.24018462, 0.58743664, 0.14456457, 0.55360801, 0.23843632,
#         0.68942145],
#        [0.22321664, 0.51684371, 0.32132985, 0.45595998, 0.66035985,
#         0.68877034, 0.67399925, 0.53246376, 0.21910789, 0.7409956 ,
#         0.75506763, 0.19715715, 0.44863029, 0.27773239, 0.51313831,
#         0.94121962, 0.63605484, 0.82275638, 0.42200295, 0.27101654,
#         0.75226882, 0.94227527, 0.15977889, 0.51029103, 0.31714182,
#         0.33563136, 0.86230684, 0.54264811, 0.72633904, 0.33767876,
#         0.29770847, 0.61317331, 0.80273022, 0.19715715, 0.52079172,
#         0.32385316, 0.16083629, 0.79673065, 0.26951016, 0.56455071,
#         0.32720538, 0.36677752, 0.32985575, 0.73692723, 0.21821532,
#         0.55609337, 0.34641562, 0.26951506, 0.73667524, 0.24018462,
#         0.58743664, 0.14456457, 0.55360801, 0.23843632, 0.68942145,
#         0.17609897, 0.58164802, 0.36274844, 0.68599113, 0.76181575,
#         0.19632485, 0.54006098, 0.20689715, 0.72459432, 0.23139131,
#         0.68058206],
#        [0.19715715, 0.44863029, 0.27773239, 0.51313831, 0.94121962,
#         0.63605484, 0.82275638, 0.42200295, 0.27101654, 0.75226882,
#         0.94227527, 0.15977889, 0.51029103, 0.31714182, 0.33563136,
#         0.86230684, 0.54264811, 0.72633904, 0.33767876, 0.29770847,
#         0.61317331, 0.80273022, 0.19715715, 0.52079172, 0.32385316,
#         0.16083629, 0.79673065, 0.26951016, 0.56455071, 0.32720538,
#         0.36677752, 0.32985575, 0.73692723, 0.21821532, 0.55609337,
#         0.34641562, 0.26951506, 0.73667524, 0.24018462, 0.58743664,
#         0.14456457, 0.55360801, 0.23843632, 0.68942145, 0.17609897,
#         0.58164802, 0.36274844, 0.68599113, 0.76181575, 0.19632485,
#         0.54006098, 0.20689715, 0.72459432, 0.23139131, 0.68058206,
#         0.16820216, 0.75784391, 0.47536108, 1.        , 0.77614346,
#         0.63538186, 0.53769913, 0.18837283, 0.74242195, 0.64724847,
#         0.71647171]])

# %%
test_X = test_X.reshape((test_X.shape[0], n_months, n_features))

# %%
test_X.shape
# Out:
# (12, 6, 11)

# %%
# Assuming test_X.shape is (22, 4, 11) and you are forecasting one feature

# Forecasting
last_sequence = test_X[-1]
forecast = []

for i in range(6):
    prediction = model.predict(last_sequence.reshape(1, n_months, n_features))
    forecast.append(prediction[0, 0])
    last_sequence = np.roll(last_sequence, -1)
    last_sequence[-1] = prediction[0, 0]

# Create dummy data for inverse transformation
dummy_data = np.zeros((len(forecast), n_features))
# Place the forecasted values in the appropriate column (assuming it's the first column)
dummy_data[:, 0] = forecast

# Inverse transform
inv_forecast = scaler.inverse_transform(dummy_data)
# Extract the forecasted values
inv_forecast = inv_forecast[:, 0]

# Create a DataFrame for the forecasted values
forecast_dates = pd.date_range(start=df.index[-1], periods=13, freq='MS')[1:]
forecast_df = pd.DataFrame({'forecasted_data': inv_forecast}, index=forecast_dates)

# Print or visualize the forecasted data
print(forecast_df)
# Out:
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1224], line 25
#      23 # Create a DataFrame for the forecasted values
#      24 forecast_dates = pd.date_range(start=df.index[-1], periods=13, freq='MS')[1:]
# ---> 25 forecast_df = pd.DataFrame({'forecasted_data': inv_forecast}, index=forecast_dates)
#      27 # Print or visualize the forecasted data
#      28 print(forecast_df)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     730     mgr = self._init_mgr(
#     731         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     732     )
#     734 elif isinstance(data, dict):
#     735     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 736     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     737 elif isinstance(data, ma.MaskedArray):
#     738     from numpy.ma import mrecords
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:119, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:630, in _homogenize(data, index, dtype)
#     627         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     629     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 630     com.require_length_match(val, index)
#     631     refs.append(None)
#     633 homogenized.append(val)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (6) does not match length of index (12)

# %%
# Forecasting
last_sequence = test_X[-1]  # Last known sequence
forecast = []

# Set the number of months to forecast
future_steps = 6

for i in range(future_steps):
    # Predict the next step
    prediction = model.predict(last_sequence.reshape(1, n_months, n_features))
    forecast.append(prediction[0, 0])
    
    # Roll the sequence and update only the target feature
    last_sequence = np.roll(last_sequence, -1, axis=1)
    last_sequence[:, -1] = prediction[0, 0]  # Update target feature, assuming it's at index 0

# Inverse transform
# Prepare the data for inverse transformation
forecast_data = np.zeros((len(forecast), n_features))
forecast_data[:, 0] = forecast  # Update the target feature with forecasted values
last_known_features = test_X[-1, -1, 1:]  # Last known values of the other features
forecast_data[:, 1:] = last_known_features  # Update other features with the last known values

inv_forecast = scaler.inverse_transform(forecast_data)
inv_forecast = inv_forecast[:, 0]  # Extract the forecasted target values

# Create a DataFrame for the forecasted values
forecast_dates = pd.date_range(start=df.index[-1], periods=future_steps + 1, freq='MS')[1:]
forecast_df = pd.DataFrame({'forecasted_data': inv_forecast}, index=forecast_dates)

# Print or visualize the forecasted data
print(forecast_df)
# Out:
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
#             forecasted_data
# 2023-12-01      1052.514025
# 2024-01-01      1426.924862
# 2024-02-01      1256.427146
# 2024-03-01      1352.026176
# 2024-04-01      1699.491450
# 2024-05-01      1266.200892

# %%
# now plot the true values of the train and test set and then the future predicted values, plot after 2016

# make plot line bold and bigger
plt.rcParams['lines.linewidth'] = 3
plt.figure(figsize=(12, 6))
plt.plot(df.index[:n_train_months+n_months], df['pko_fob_malaysia'][:n_train_months+n_months], label='Train True Values')
plt.plot(df.index[n_train_months+n_months:], df['pko_fob_malaysia'][n_train_months+n_months:], label='Test True Values')
#plot with dashed line the line connecting the last value of train and first value of test set
#plt.plot([df.index[n_train_months+n_months-1], df.index[n_train_months+n_months]], [df['pko_cif_rotterdam'][n_train_months+n_months-1], df['pko_cif_rotterdam'][n_train_months+n_months]], linestyle='dashed')
# also plot the predicted test values
plt.plot(df_results['date'], df_results['prediction'], label='Predicted Test Values')
plt.plot(forecast_df.index, forecast_df['forecasted_data'], label='Forecasted Values', color='red')
plt.title('GRU Model Predictions')
plt.xlabel('Date')
plt.ylabel('Palm Kernel Oil Price (FOB Malaysia)')
# add a nice theme 
plt.style.use('seaborn-v0_8-pastel')
plt.legend()
plt.show()
